# %%
import pandas as pd
from bs4 import BeautifulSoup
import spacy
import requests
import csv
from datetime import datetime

# %%
url = 'https://millercenter.org/the-presidency/presidential-speeches?field_president_target_id[8396]=8396'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
speeches = []
transcripts = soup.findAll("div", attrs={"class" : "views-field-title"})

# %%
csv_file_path = 'speech_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(['Title', 'Link', 'President', 'Date', 'Summary', 'Speech'])

    for i, transcript in enumerate(transcripts):
      if i < 24:
        link_url = transcript.find('a')['href']
        link_response = requests.get(link_url)
        link_html_content = link_response.content
        link_soup = BeautifulSoup(link_html_content, 'html.parser')
        link_text = link_soup.find("div", attrs = {'class': "transcript-inner"}).text.strip()
        speeches.append(link_text)
        title = transcript.text.strip()
        link = link_url
        president = link_soup.find("p", attrs = {'class': "president-name"}).text.strip()
        date = link_soup.find("p", attrs = {'class': "episode-date"}).text.strip()
        summary = link_soup.find("div", attrs = {'class': "about-sidebar--intro"}).text.strip()

        csv_writer.writerow([title, link, president, date, summary, link_text])

# %% [markdown]
# Rename the columns and change the format of the date.

# %%
data = pd.read_csv('speech_data.csv')
data = data.rename(columns={'Title': 'Speech Title', 'Link': 'URL', 'Speech': 'Transcript'})

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(link_text)

# %%
data['Doc'] = data['Transcript'].apply(nlp)

# %% [markdown]
# Create corpus files in the text format

# %%
for i, row in data.iterrows():
    formatted_date = datetime.strptime(row['Date'], "%B %d, %Y").strftime("%Y%m%d")
    filename = f"transcript_{formatted_date}.txt"

    with open(filename, 'w', encoding='utf-8') as txt_file:
      txt_file.write(row['Transcript'])

# %%
for token in doc:
    print(token.text, token.pos_)
# Out:
# Transcript PROPN
#
#  SPACE
# Last ADJ
# night NOUN
# , PUNCT
# the DET
# United PROPN
# States PROPN
# brought VERB
# the DET
# world NOUN
# ’s PART
# number NOUN
# one NUM
# terrorist ADJ
# leader NOUN
# to ADP
# justice NOUN
# . PUNCT
# Abu PROPN
# Bakr PROPN
# al PROPN
# - PUNCT
# Baghdadi PROPN
# is AUX
# dead ADJ
# . PUNCT
#    SPACE
# He PRON
# was AUX
# the DET
# founder NOUN
# and CCONJ
# leader NOUN
# of ADP
# ISIS PROPN
# , PUNCT
# the DET
# most ADV
# ruthless ADJ
# and CCONJ
# violent ADJ
# terror NOUN
# organization NOUN
# in ADP
# the DET
# World PROPN
# . PUNCT
#    SPACE
# The DET
# United PROPN
# States PROPN
# has AUX
# been AUX
# searching VERB
# for ADP
# Baghdadi PROPN
# for ADP
# many ADJ
# years NOUN
# . PUNCT
#    SPACE
# Capturing NOUN
# or CCONJ
# killing VERB
# Baghdadi PROPN
# has AUX
# been AUX
# the DET
# top ADJ
# national ADJ
# security NOUN
# priority NOUN
# of ADP
# my PRON
# Administration PROPN
# . PUNCT
#    SPACE
# U.S. PROPN
# Special PROPN
# Operations PROPN
# forces NOUN
# executed VERB
# a DET
# dangerous ADJ
# and CCONJ
# daring ADJ
# nighttime ADJ
# raid NOUN
# into ADP
# Northwestern PROPN
# Syria PROPN
# to PART
# accomplish VERB
# this DET
# mission NOUN
# . PUNCT
#
#  SPACE
# No DET
# U.S. PROPN
# personnel NOUN
# were AUX
# lost VERB
# in ADP
# the DET
# operation NOUN
# , PUNCT
# while SCONJ
# a DET
# large ADJ
# number NOUN
# of ADP
# Baghdadi NOUN
# ’s PART
# fighters NOUN
# and CCONJ
# companions NOUN
# were AUX
# killed VERB
# with ADP
# him PRON
# . PUNCT
#    SPACE
# He PRON
# died VERB
# after ADP
# running VERB
# into ADP
# a DET
# dead ADJ
# - PUNCT
# end NOUN
# tunnel NOUN
# , PUNCT
# whimpering NOUN
# and CCONJ
# crying NOUN
# and CCONJ
# screaming VERB
# . PUNCT
#    SPACE
# The DET
# compound NOUN
# had AUX
# been AUX
# cleared VERB
# by ADP
# this DET
# time NOUN
# , PUNCT
# with ADP
# people NOUN
# either CCONJ
# surrendering VERB
# or CCONJ
# being AUX
# shot VERB
# and CCONJ
# killed VERB
# . PUNCT
#    SPACE
# Eleven PROPN
# young ADJ
# children NOUN
# were AUX
# moved VERB
# out ADP
# of ADP
# the DET
# house NOUN
# un PROPN
# - NOUN
# injured VERB
# . PUNCT
#    SPACE
# The DET
# only ADJ
# ones NOUN
# remaining VERB
# were AUX
# Baghdadi NOUN
# in ADP
# the DET
# tunnel NOUN
# , PUNCT
# who PRON
# had AUX
# dragged VERB
# three NUM
# children NOUN
# with ADP
# him PRON
# to ADP
# certain ADJ
# death NOUN
# . PUNCT
#    SPACE
# He PRON
# reached VERB
# the DET
# end NOUN
# of ADP
# the DET
# tunnel NOUN
# , PUNCT
# as SCONJ
# our PRON
# dogs NOUN
# chased VERB
# him PRON
# down ADP
# . PUNCT
# He PRON
# ignited VERB
# his PRON
# vest NOUN
# , PUNCT
# killing VERB
# himself PRON
# and CCONJ
# the DET
# three NUM
# children NOUN
# . PUNCT
#    SPACE
# His PRON
# body NOUN
# was AUX
# mutilated VERB
# by ADP
# the DET
# blast NOUN
# , PUNCT
# but CCONJ
# test NOUN
# results NOUN
# gave VERB
# certain ADJ
# and CCONJ
# positive ADJ
# identification NOUN
# . PUNCT
#
#  SPACE
# The DET
# thug NOUN
# who PRON
# tried VERB
# so ADV
# hard ADV
# to PART
# intimidate VERB
# others NOUN
# spent VERB
# his PRON
# last ADJ
# moments NOUN
# in ADP
# utter ADJ
# fear NOUN
# , PUNCT
# panic NOUN
# and CCONJ
# dread NOUN
# – PUNCT
# terrified VERB
# of ADP
# the DET
# American PROPN
# Forces PROPN
# bearing VERB
# down ADP
# . PUNCT
#
#  SPACE
# We PRON
# were AUX
# in ADP
# the DET
# compound NOUN
# for ADP
# approximately ADV
# 2 NUM
# hours NOUN
# , PUNCT
# and CCONJ
# after SCONJ
# the DET
# mission NOUN
# was AUX
# accomplished VERB
# we PRON
# took VERB
# highly ADV
# sensitive ADJ
# material NOUN
# and CCONJ
# information NOUN
# from ADP
# the DET
# raid NOUN
# . PUNCT
#
#  SPACE
# Baghdadi PROPN
# ’s PART
# demise NOUN
# demonstrates VERB
# America PROPN
# ’s PART
# relentless ADJ
# pursuit NOUN
# of ADP
# terrorist ADJ
# leaders NOUN
# , PUNCT
# and CCONJ
# our PRON
# commitment NOUN
# to ADP
# the DET
# enduring ADJ
# and CCONJ
# total ADJ
# defeat NOUN
# of ADP
# ISIS PROPN
# ! PUNCT
#
#  SPACE
# The DET
# reach NOUN
# of ADP
# America PROPN
# is AUX
# long ADJ
# . PUNCT
#    SPACE
# As SCONJ
# you PRON
# know VERB
# , PUNCT
# last ADJ
# month NOUN
# we PRON
# announced VERB
# that SCONJ
# we PRON
# recently ADV
# killed VERB
# Hamza PROPN
# Bin PROPN
# Laden PROPN
# , PUNCT
# the DET
# very ADV
# violent ADJ
# son NOUN
# of ADP
# Osama PROPN
# Bin PROPN
# Laden PROPN
# , PUNCT
# who PRON
# was AUX
# saying VERB
# very ADV
# bad ADJ
# things NOUN
# . PUNCT
#
#  SPACE
# He PRON
# was AUX
# the DET
# heir NOUN
# apparent ADJ
# to ADP
# Al PROPN
# Qaeda PROPN
# . PUNCT
# Terrorists NOUN
# who PRON
# oppress VERB
# and CCONJ
# murder NOUN
# innocent ADJ
# people NOUN
# should AUX
# never ADV
# sleep VERB
# soundly ADV
# , PUNCT
# knowing VERB
# that SCONJ
# we PRON
# will AUX
# completely ADV
# destroy VERB
# them PRON
# . PUNCT
# These DET
# savage NOUN
# monsters NOUN
# will AUX
# not PART
# escape VERB
# their PRON
# fate NOUN
# – PUNCT
# and CCONJ
# they PRON
# will AUX
# not PART
# escape VERB
# the DET
# final ADJ
# judgement NOUN
# of ADP
# God PROPN
# . PUNCT
#
#  SPACE
# Baghdadi PROPN
# has AUX
# been AUX
# on ADP
# the DET
# run NOUN
# for ADP
# many ADJ
# years NOUN
# , PUNCT
# long ADV
# before SCONJ
# I PRON
# took VERB
# office NOUN
# . PUNCT
# At ADP
# my PRON
# direction NOUN
# , PUNCT
# as ADP
# Commander PROPN
# - PUNCT
# in ADP
# - PUNCT
# Chief PROPN
# , PUNCT
# the DET
# United PROPN
# States PROPN
# obliterated VERB
# his PRON
# ‘ PUNCT
# caliphate NOUN
# ’ PUNCT
# in ADP
# March PROPN
# of ADP
# this DET
# year NOUN
# . PUNCT
#    SPACE
# Today NOUN
# ’s PART
# events NOUN
# are AUX
# another DET
# reminder NOUN
# that SCONJ
# we PRON
# will AUX
# continue VERB
# to PART
# pursue VERB
# the DET
# remaining VERB
# ISIS PROPN
# terrorists NOUN
# to ADP
# their PRON
# brutal ADJ
# end NOUN
# . PUNCT
#
#  SPACE
# Baghdadi PROPN
# and CCONJ
# the DET
# losers NOUN
# who PRON
# worked VERB
# with ADP
# him PRON
# – PUNCT
# in ADP
# some DET
# cases NOUN
# people NOUN
# who PRON
# had VERB
# no DET
# idea NOUN
# what PRON
# they PRON
# were AUX
# getting VERB
# into ADP
# and CCONJ
# how SCONJ
# dangerous ADJ
# and CCONJ
# unglamorous ADJ
# it PRON
# was AUX
# – PUNCT
# killed VERB
# many ADJ
# people NOUN
# . PUNCT
#    SPACE
# Their PRON
# murder NOUN
# of ADP
# innocent ADJ
# Americans PROPN
# Jim PROPN
# Foley PROPN
# , PUNCT
# Steven PROPN
# Sotloff PROPN
# , PUNCT
# Peter PROPN
# Kassig PROPN
# , PUNCT
# and CCONJ
# Kayla PROPN
# Mueller PROPN
# were AUX
# especially ADV
# heinous ADJ
# . PUNCT
#    SPACE
# The DET
# shocking ADJ
# publicized VERB
# murder NOUN
# of ADP
# a DET
# Jordanian ADJ
# pilot NOUN
# who PRON
# was AUX
# burned VERB
# alive ADJ
# in ADP
# a DET
# cage NOUN
# for SCONJ
# all PRON
# to PART
# see VERB
# , PUNCT
# and CCONJ
# the DET
# execution NOUN
# of ADP
# Christians PROPN
# in ADP
# Libya PROPN
# and CCONJ
# Egypt PROPN
# , PUNCT
# as ADV
# well ADV
# as ADP
# the DET
# genocidal ADJ
# mass ADJ
# murder NOUN
# of ADP
# Yazidis PROPN
# , PUNCT
# rank NOUN
# ISIS PROPN
# among ADP
# the DET
# most ADV
# depraved ADJ
# organizations NOUN
# in ADP
# history NOUN
# . PUNCT
#
#  SPACE
# The DET
# forced VERB
# religious ADJ
# conversions NOUN
# , PUNCT
# the DET
# orange ADJ
# suits NOUN
# prior ADV
# to ADP
# many ADJ
# beheadings NOUN
# , PUNCT
# all PRON
# of ADP
# which PRON
# were AUX
# openly ADV
# displayed VERB
# for ADP
# the DET
# world NOUN
# – PUNCT
# this PRON
# was AUX
# all PRON
# Abu PROPN
# Bakr PROPN
# al PROPN
# - PUNCT
# Baghdadi PROPN
# ’s PART
# work NOUN
# . PUNCT
#    SPACE
# He PRON
# was AUX
# vicious ADJ
# and CCONJ
# violent ADJ
# , PUNCT
# and CCONJ
# he PRON
# died VERB
# in ADP
# a DET
# vicious ADJ
# and CCONJ
# violent ADJ
# way NOUN
# , PUNCT
# as ADP
# a DET
# coward NOUN
# , PUNCT
# running VERB
# and CCONJ
# crying VERB
# . PUNCT
#    SPACE
# This DET
# raid NOUN
# was AUX
# impeccable ADJ
# , PUNCT
# and CCONJ
# could AUX
# only ADV
# have AUX
# taken VERB
# place NOUN
# with ADP
# the DET
# acknowledgement NOUN
# and CCONJ
# help NOUN
# of ADP
# certain ADJ
# other ADJ
# nations NOUN
# and CCONJ
# people NOUN
# . PUNCT
#
#  SPACE
# I PRON
# want VERB
# to PART
# thank VERB
# the DET
# nations NOUN
# of ADP
# Russia PROPN
# , PUNCT
# Turkey PROPN
# , PUNCT
# Syria PROPN
# and CCONJ
# Iraq PROPN
# , PUNCT
# and CCONJ
# I PRON
# also ADV
# want VERB
# to PART
# thank VERB
# the DET
# Syrian ADJ
# Kurds PROPN
# for ADP
# certain ADJ
# support NOUN
# they PRON
# were AUX
# able ADJ
# to PART
# give VERB
# us PRON
# . PUNCT
# Thank VERB
# you PRON
# as ADV
# well ADV
# to ADP
# the DET
# great ADJ
# intelligence NOUN
# professionals NOUN
# who PRON
# helped VERB
# make VERB
# this DET
# very ADV
# successful ADJ
# journey NOUN
# possible ADJ
# . PUNCT
#
#  SPACE
# I PRON
# want VERB
# to PART
# thank VERB
# the DET
# soldiers NOUN
# , PUNCT
# sailors NOUN
# , PUNCT
# airmen NOUN
# , PUNCT
# and CCONJ
# marines NOUN
# involved VERB
# in ADP
# last ADJ
# night NOUN
# ’s PART
# operation NOUN
# . PUNCT
#    SPACE
# You PRON
# are AUX
# the DET
# very ADV
# best ADJ
# there PRON
# is VERB
# anywhere ADV
# in ADP
# the DET
# world NOUN
# . PUNCT
#    SPACE
# I PRON
# want VERB
# to PART
# thank VERB
# General PROPN
# Mark PROPN
# Milley PROPN
# and CCONJ
# our PRON
# Joint PROPN
# Chiefs PROPN
# of ADP
# Staff PROPN
# , PUNCT
# and CCONJ
# I PRON
# also ADV
# want VERB
# to PART
# thank VERB
# our PRON
# professionals NOUN
# who PRON
# work VERB
# in ADP
# other ADJ
# agencies NOUN
# of ADP
# the DET
# United PROPN
# States PROPN
# government NOUN
# and CCONJ
# were AUX
# critical ADJ
# to ADP
# the DET
# mission NOUN
# ’s PART
# success NOUN
# . PUNCT
#
#  SPACE
# Last ADJ
# night NOUN
# was AUX
# a DET
# great ADJ
# night NOUN
# for ADP
# the DET
# United PROPN
# States PROPN
# and CCONJ
# for ADP
# the DET
# World PROPN
# . PUNCT
# A DET
# brutal ADJ
# killer NOUN
# , PUNCT
# one NUM
# who PRON
# has AUX
# caused VERB
# so ADV
# much ADJ
# hardship NOUN
# and CCONJ
# death NOUN
# , PUNCT
# was AUX
# violently ADV
# eliminated VERB
# – PUNCT
# he PRON
# will AUX
# never ADV
# again ADV
# harm VERB
# another DET
# innocent ADJ
# man NOUN
# , PUNCT
# woman NOUN
# or CCONJ
# child NOUN
# . PUNCT
#    SPACE
# He PRON
# died VERB
# like ADP
# a DET
# dog NOUN
# . PUNCT
#    SPACE
# He PRON
# died VERB
# like ADP
# a DET
# coward NOUN
# . PUNCT
#    SPACE
# The DET
# world NOUN
# is AUX
# now ADV
# a DET
# much ADV
# safer ADJ
# place NOUN
# . PUNCT
#
#  SPACE
# God PROPN
# bless VERB
# the DET
# United PROPN
# States PROPN
# of ADP
# America PROPN
# ! PUNCT

# %% [markdown]
# ### Tokenization

# %%
data['Tokens'] = data['Doc'].apply(lambda doc: [token.text for token in doc])
data.head(5)
# Out:
#                                         Speech Title  \
# 0                 January 19, 2021: Farewell Address
# 1  January 13, 2021: Statement about the Violence...
# 2  January 7, 2021: Message After Pro-Trump Mob O...
# 3  January 6, 2021: Speech Urging Supporters to G...
# 4     November 5, 2020: Remarks on the 2020 Election
#
#                                                  URL     President  \
# 0  https://millercenter.org/the-presidency/presid...  Donald Trump
# 1  https://millercenter.org/the-presidency/presid...  Donald Trump
# 2  https://millercenter.org/the-presidency/presid...  Donald Trump
# 3  https://millercenter.org/the-presidency/presid...  Donald Trump
# 4  https://millercenter.org/the-presidency/presid...  Donald Trump
#
#                 Date                                            Summary  \
# 0   January 19, 2021  President Donald Trump gives his farewell addr...
# 1   January 13, 2021  A week after a mob stormed the US Capitol, Pre...
# 2   January 07, 2021  The day after a mob overran the United States ...
# 3   January 06, 2021  On January 6, 2021, Trump supporters and white...
# 4  November 05, 2020  President Trump makes remarks at the White Hou...
#
#                                           Transcript  \
# 0  Transcript\nMy fellow Americans: Four years ag...
# 1  Transcript\nMy fellow Americans, \nI want to s...
# 2  Transcript\nI would like to begin by addressin...
# 3  Transcript\nI know your pain. I know your hurt...
# 4  Transcript\nTHE PRESIDENT: Good evening. I’d l...
#
#                                                  Doc  \
# 0  (Transcript, \n, My, fellow, Americans, :, Fou...
# 1  (Transcript, \n, My, fellow, Americans, ,,  \n...
# 2  (Transcript, \n, I, would, like, to, begin, by...
# 3  (Transcript, \n, I, know, your, pain, ., I, kn...
# 4  (Transcript, \n, THE, PRESIDENT, :, Good, even...
#
#                                               Tokens
# 0  [Transcript, \n, My, fellow, Americans, :, Fou...
# 1  [Transcript, \n, My, fellow, Americans, ,,  \n...
# 2  [Transcript, \n, I, would, like, to, begin, by...
# 3  [Transcript, \n, I, know, your, pain, ., I, kn...
# 4  [Transcript, \n, THE, PRESIDENT, :, Good, even...

# %% [markdown]
# ### Lemmatization

# %%
data['Lemmas'] = data['Doc'].apply(lambda doc: [token.lemma_ for token in doc])

# %%
print(f'"China" appears in the text tokens column ' + str(data['Tokens'].apply(lambda x: x.count('write')).sum()) + 'times.')
print(f'"China" appears in the lemmas column ' + str(data['Lemmas'].apply(lambda x: x.count('write')).sum()) + 'times.')
# Out:
# "China" appears in the text tokens column 11times.
# "China" appears in the lemmas column 41times.

# %% [markdown]
# #### Text Annotation

# %% [markdown]
# ### Parts-of-speech

# %%
data['POS'] = data['Doc'].apply(lambda doc: [(token.text, token.pos_, token.tag_) for token in doc])

# %%
list(data['POS'])
# Out:
# [[('Transcript', 'PROPN', 'NNP'),
#   ('\n', 'SPACE', '_SP'),
#   ('My', 'PRON', 'PRP$'),
#   ('fellow', 'ADJ', 'JJ'),
#   ('Americans', 'PROPN', 'NNPS'),
#   (':', 'PUNCT', ':'),
#   ('Four', 'NUM', 'CD'),
#   ('years', 'NOUN', 'NNS'),
#   ('ago', 'ADV', 'RB'),
#   (',', 'PUNCT', ','),
#   ('we', 'PRON', 'PRP'),
#   ('launched', 'VERB', 'VBD'),
#   ('a', 'DET', 'DT'),
#   ('great', 'ADJ', 'JJ'),
#   ('national', 'ADJ', 'JJ'),
#   ('effort', 'NOUN', 'NN'),
#   ('to', 'PART', 'TO'),
#   ('rebuild', 'VERB', 'VB'),
#   ('our', 'PRON', 'PRP$'),
#   ('country', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('to', 'PART', 'TO'),
#   ('renew', 'VERB', 'VB'),
#   ('its', 'PRON', 'PRP$'),
#   ('spirit', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('to', 'PART', 'TO'),
#   ('restore', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('allegiance', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('this', 'DET', 'DT'),
#   ('government', 'NOUN', 'NN'),
#   ('to', 'ADP', 'IN'),
#   ('its', 'PRON', 'PRP$'),
#   ('citizens', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('In', 'ADP', 'IN'),
#   ('short', 'ADJ', 'JJ'),
#   (',', 'PUNCT', ','),
#   ('we', 'PRON', 'PRP'),
#   ('embarked', 'VERB', 'VBD'),
#   ('on', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('mission', 'NOUN', 'NN'),
#   ('to', 'PART', 'TO'),
#   ('make', 'VERB', 'VB'),
#   ('America', 'PROPN', 'NNP'),
#   ('great', 'ADJ', 'JJ'),
#   ('again', 'ADV', 'RB'),
#   ('—', 'PUNCT', ':'),
#   ('for', 'ADP', 'IN'),
#   ('all', 'DET', 'DT'),
#   ('Americans', 'PROPN', 'NNPS'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('As', 'SCONJ', 'IN'),
#   ('I', 'PRON', 'PRP'),
#   ('conclude', 'VERB', 'VBP'),
#   ('my', 'PRON', 'PRP$'),
#   ('term', 'NOUN', 'NN'),
#   ('as', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('45th', 'ADJ', 'JJ'),
#   ('President', 'PROPN', 'NNP'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('United', 'PROPN', 'NNP'),
#   ('States', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('I', 'PRON', 'PRP'),
#   ('stand', 'VERB', 'VBP'),
#   ('before', 'ADP', 'IN'),
#   ('you', 'PRON', 'PRP'),
#   ('truly', 'ADV', 'RB'),
#   ('proud', 'ADJ', 'JJ'),
#   ('of', 'ADP', 'IN'),
#   ('what', 'PRON', 'WP'),
#   ('we', 'PRON', 'PRP'),
#   ('have', 'AUX', 'VBP'),
#   ('achieved', 'VERB', 'VBN'),
#   ('together', 'ADV', 'RB'),
#   ('.', 'PUNCT', '.'),
#   ('We', 'PRON', 'PRP'),
#   ('did', 'VERB', 'VBD'),
#   ('what', 'PRON', 'WP'),
#   ('we', 'PRON', 'PRP'),
#   ('came', 'VERB', 'VBD'),
#   ('here', 'ADV', 'RB'),
#   ('to', 'PART', 'TO'),
#   ('do', 'VERB', 'VB'),
#   ('—', 'PUNCT', ':'),
#   ('and', 'CCONJ', 'CC'),
#   ('so', 'ADV', 'RB'),
#   ('much', 'ADV', 'RB'),
#   ('more', 'ADJ', 'JJR'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('This', 'DET', 'DT'),
#   ('week', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('we', 'PRON', 'PRP'),
#   ('inaugurate', 'VERB', 'VBP'),
#   ('a', 'DET', 'DT'),
#   ('new', 'ADJ', 'JJ'),
#   ('administration', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('pray', 'VERB', 'VB'),
#   ('for', 'ADP', 'IN'),
#   ('its', 'PRON', 'PRP$'),
#   ('success', 'NOUN', 'NN'),
#   ('in', 'ADP', 'IN'),
#   ('keeping', 'VERB', 'VBG'),
#   ('America', 'PROPN', 'NNP'),
#   ('safe', 'ADJ', 'JJ'),
#   ('and', 'CCONJ', 'CC'),
#   ('prosperous', 'ADJ', 'JJ'),
#   ('.', 'PUNCT', '.'),
#   ('We', 'PRON', 'PRP'),
#   ('extend', 'VERB', 'VBP'),
#   ('our', 'PRON', 'PRP$'),
#   ('best', 'ADJ', 'JJS'),
#   ('wishes', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('we', 'PRON', 'PRP'),
#   ('also', 'ADV', 'RB'),
#   ('want', 'VERB', 'VBP'),
#   ('them', 'PRON', 'PRP'),
#   ('to', 'PART', 'TO'),
#   ('have', 'VERB', 'VB'),
#   ('luck', 'NOUN', 'NN'),
#   ('—', 'PUNCT', ':'),
#   ('a', 'DET', 'DT'),
#   ('very', 'ADV', 'RB'),
#   ('important', 'ADJ', 'JJ'),
#   ('word', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('I', 'PRON', 'PRP'),
#   ('’d', 'AUX', 'MD'),
#   ('like', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('begin', 'VERB', 'VB'),
#   ('by', 'ADP', 'IN'),
#   ('thanking', 'VERB', 'VBG'),
#   ('just', 'ADV', 'RB'),
#   ('a', 'DET', 'DT'),
#   ('few', 'ADJ', 'JJ'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('amazing', 'ADJ', 'JJ'),
#   ('people', 'NOUN', 'NNS'),
#   ('who', 'PRON', 'WP'),
#   ('made', 'VERB', 'VBD'),
#   ('our', 'PRON', 'PRP$'),
#   ('remarkable', 'ADJ', 'JJ'),
#   ('journey', 'NOUN', 'NN'),
#   ('possible', 'ADJ', 'JJ'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('First', 'ADV', 'RB'),
#   (',', 'PUNCT', ','),
#   ('let', 'VERB', 'VB'),
#   ('me', 'PRON', 'PRP'),
#   ('express', 'VERB', 'VB'),
#   ('my', 'PRON', 'PRP$'),
#   ('overwhelming', 'ADJ', 'JJ'),
#   ('gratitude', 'NOUN', 'NN'),
#   ('for', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('love', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('support', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('spectacular', 'ADJ', 'JJ'),
#   ('First', 'PROPN', 'NNP'),
#   ('Lady', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('Melania', 'PROPN', 'NNP'),
#   ('.', 'PUNCT', '.'),
#   ('Let', 'VERB', 'VB'),
#   ('me', 'PRON', 'PRP'),
#   ('also', 'ADV', 'RB'),
#   ('share', 'VERB', 'VB'),
#   ('my', 'PRON', 'PRP$'),
#   ('deepest', 'ADJ', 'JJS'),
#   ('appreciation', 'NOUN', 'NN'),
#   ('to', 'ADP', 'IN'),
#   ('my', 'PRON', 'PRP$'),
#   ('daughter', 'NOUN', 'NN'),
#   ('Ivanka', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('my', 'PRON', 'PRP$'),
#   ('son', 'NOUN', 'NN'),
#   ('-', 'PUNCT', 'HYPH'),
#   ('in', 'ADP', 'IN'),
#   ('-', 'PUNCT', 'HYPH'),
#   ('law', 'NOUN', 'NN'),
#   ('Jared', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('to', 'ADP', 'IN'),
#   ('Barron', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('Don', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('Eric', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('Tiffany', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('Lara', 'PROPN', 'NNP'),
#   ('.', 'PUNCT', '.'),
#   ('You', 'PRON', 'PRP'),
#   ('fill', 'VERB', 'VBP'),
#   ('my', 'PRON', 'PRP$'),
#   ('world', 'NOUN', 'NN'),
#   ('with', 'ADP', 'IN'),
#   ('light', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('with', 'ADP', 'IN'),
#   ('joy', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('I', 'PRON', 'PRP'),
#   ('also', 'ADV', 'RB'),
#   ('want', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('thank', 'VERB', 'VB'),
#   ('Vice', 'PROPN', 'NNP'),
#   ('President', 'PROPN', 'NNP'),
#   ('Mike', 'PROPN', 'NNP'),
#   ('Pence', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('his', 'PRON', 'PRP$'),
#   ('wonderful', 'ADJ', 'JJ'),
#   ('wife', 'NOUN', 'NN'),
#   ('Karen', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('the', 'DET', 'DT'),
#   ('entire', 'ADJ', 'JJ'),
#   ('Pence', 'PROPN', 'NNP'),
#   ('family', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('Thank', 'VERB', 'VBP'),
#   ('you', 'PRON', 'PRP'),
#   ('as', 'ADV', 'RB'),
#   ('well', 'ADV', 'RB'),
#   ('to', 'ADP', 'IN'),
#   ('my', 'PRON', 'PRP$'),
#   ('Chief', 'PROPN', 'NNP'),
#   ('of', 'ADP', 'IN'),
#   ('Staff', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('Mark', 'PROPN', 'NNP'),
#   ('Meadows', 'PROPN', 'NNP'),
#   (';', 'PUNCT', ':'),
#   ('the', 'DET', 'DT'),
#   ('dedicated', 'ADJ', 'JJ'),
#   ('members', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('White', 'PROPN', 'NNP'),
#   ('House', 'PROPN', 'NNP'),
#   ('Staff', 'PROPN', 'NNP'),
#   ('and', 'CCONJ', 'CC'),
#   ('the', 'DET', 'DT'),
#   ('Cabinet', 'PROPN', 'NNP'),
#   (';', 'PUNCT', ':'),
#   ('and', 'CCONJ', 'CC'),
#   ('all', 'DET', 'PDT'),
#   ('the', 'DET', 'DT'),
#   ('incredible', 'ADJ', 'JJ'),
#   ('people', 'NOUN', 'NNS'),
#   ('across', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('administration', 'NOUN', 'NN'),
#   ('who', 'PRON', 'WP'),
#   ('poured', 'VERB', 'VBD'),
#   ('out', 'ADP', 'RP'),
#   ('their', 'PRON', 'PRP$'),
#   ('heart', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('soul', 'NOUN', 'NN'),
#   ('to', 'PART', 'TO'),
#   ('fight', 'VERB', 'VB'),
#   ('for', 'ADP', 'IN'),
#   ('America', 'PROPN', 'NNP'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('I', 'PRON', 'PRP'),
#   ('also', 'ADV', 'RB'),
#   ('want', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('take', 'VERB', 'VB'),
#   ('a', 'DET', 'DT'),
#   ('moment', 'NOUN', 'NN'),
#   ('to', 'PART', 'TO'),
#   ('thank', 'VERB', 'VB'),
#   ('a', 'DET', 'DT'),
#   ('truly', 'ADV', 'RB'),
#   ('exceptional', 'ADJ', 'JJ'),
#   ('group', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('people', 'NOUN', 'NNS'),
#   (':', 'PUNCT', ':'),
#   ('the', 'DET', 'DT'),
#   ('United', 'PROPN', 'NNP'),
#   ('States', 'PROPN', 'NNP'),
#   ('Secret', 'PROPN', 'NNP'),
#   ('Service', 'PROPN', 'NNP'),
#   ('.', 'PUNCT', '.'),
#   ('My', 'PRON', 'PRP$'),
#   ('family', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('I', 'PRON', 'PRP'),
#   ('will', 'AUX', 'MD'),
#   ('forever', 'ADV', 'RB'),
#   ('be', 'AUX', 'VB'),
#   ('in', 'ADP', 'IN'),
#   ('your', 'PRON', 'PRP$'),
#   ('debt', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('My', 'PRON', 'PRP$'),
#   ('profound', 'ADJ', 'JJ'),
#   ('gratitude', 'NOUN', 'NN'),
#   ('as', 'ADV', 'RB'),
#   ('well', 'ADV', 'RB'),
#   ('to', 'ADP', 'IN'),
#   ('everyone', 'PRON', 'NN'),
#   ('in', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('White', 'PROPN', 'NNP'),
#   ('House', 'PROPN', 'NNP'),
#   ('Military', 'PROPN', 'NNP'),
#   ('Office', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('the', 'DET', 'DT'),
#   ('teams', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('Marine', 'PROPN', 'NNP'),
#   ('One', 'PROPN', 'NNP'),
#   ('and', 'CCONJ', 'CC'),
#   ('Air', 'PROPN', 'NNP'),
#   ('Force', 'PROPN', 'NNP'),
#   ('One', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('every', 'DET', 'DT'),
#   ('member', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('Armed', 'PROPN', 'NNP'),
#   ('Forces', 'PROPN', 'NNPS'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('state', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('local', 'ADJ', 'JJ'),
#   ('law', 'NOUN', 'NN'),
#   ('enforcement', 'NOUN', 'NN'),
#   ('all', 'ADV', 'RB'),
#   ('across', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('country', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('Most', 'ADJ', 'JJS'),
#   ('of', 'ADP', 'IN'),
#   ('all', 'PRON', 'DT'),
#   (',', 'PUNCT', ','),
#   ('I', 'PRON', 'PRP'),
#   ('want', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('thank', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('American', 'ADJ', 'JJ'),
#   ('people', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('To', 'PART', 'TO'),
#   ('serve', 'VERB', 'VB'),
#   ('as', 'SCONJ', 'IN'),
#   ('your', 'PRON', 'PRP$'),
#   ('President', 'PROPN', 'NNP'),
#   ('has', 'AUX', 'VBZ'),
#   ('been', 'AUX', 'VBN'),
#   ('an', 'DET', 'DT'),
#   ('honor', 'NOUN', 'NN'),
#   ('beyond', 'ADP', 'IN'),
#   ('description', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('Thank', 'VERB', 'VBP'),
#   ('you', 'PRON', 'PRP'),
#   ('for', 'ADP', 'IN'),
#   ('this', 'DET', 'DT'),
#   ('extraordinary', 'ADJ', 'JJ'),
#   ('privilege', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('And', 'CCONJ', 'CC'),
#   ('that', 'PRON', 'DT'),
#   ('’s', 'VERB', 'VBZ'),
#   ('what', 'PRON', 'WP'),
#   ('it', 'PRON', 'PRP'),
#   ('is', 'AUX', 'VBZ'),
#   ('—', 'PUNCT', ':'),
#   ('a', 'DET', 'DT'),
#   ('great', 'ADJ', 'JJ'),
#   ('privilege', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('a', 'DET', 'DT'),
#   ('great', 'ADJ', 'JJ'),
#   ('honor', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('We', 'PRON', 'PRP'),
#   ('must', 'AUX', 'MD'),
#   ('never', 'ADV', 'RB'),
#   ('forget', 'VERB', 'VB'),
#   ('that', 'SCONJ', 'IN'),
#   ('while', 'SCONJ', 'IN'),
#   ('Americans', 'PROPN', 'NNPS'),
#   ('will', 'AUX', 'MD'),
#   ('always', 'ADV', 'RB'),
#   ('have', 'VERB', 'VB'),
#   ('our', 'PRON', 'PRP$'),
#   ('disagreements', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('we', 'PRON', 'PRP'),
#   ('are', 'AUX', 'VBP'),
#   ('a', 'DET', 'DT'),
#   ('nation', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('incredible', 'ADJ', 'JJ'),
#   (',', 'PUNCT', ','),
#   ('decent', 'ADJ', 'JJ'),
#   (',', 'PUNCT', ','),
#   ('faithful', 'ADJ', 'JJ'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('peace', 'NOUN', 'NN'),
#   ('-', 'PUNCT', 'HYPH'),
#   ('loving', 'VERB', 'VBG'),
#   ('citizens', 'NOUN', 'NNS'),
#   ('who', 'PRON', 'WP'),
#   ('all', 'PRON', 'DT'),
#   ('want', 'VERB', 'VBP'),
#   ('our', 'PRON', 'PRP$'),
#   ('country', 'NOUN', 'NN'),
#   ('to', 'PART', 'TO'),
#   ('thrive', 'VERB', 'VB'),
#   ('and', 'CCONJ', 'CC'),
#   ('flourish', 'VERB', 'VB'),
#   ('and', 'CCONJ', 'CC'),
#   ('be', 'AUX', 'VB'),
#   ('very', 'ADV', 'RB'),
#   (',', 'PUNCT', ','),
#   ('very', 'ADV', 'RB'),
#   ('successful', 'ADJ', 'JJ'),
#   ('and', 'CCONJ', 'CC'),
#   ('good', 'ADJ', 'JJ'),
#   ('.', 'PUNCT', '.'),
#   ('We', 'PRON', 'PRP'),
#   ('are', 'AUX', 'VBP'),
#   ('a', 'DET', 'DT'),
#   ('truly', 'ADV', 'RB'),
#   ('magnificent', 'ADJ', 'JJ'),
#   ('nation', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('All', 'DET', 'DT'),
#   ('Americans', 'PROPN', 'NNPS'),
#   ('were', 'AUX', 'VBD'),
#   ('horrified', 'VERB', 'VBN'),
#   ('by', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('assault', 'NOUN', 'NN'),
#   ('on', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('Capitol', 'PROPN', 'NNP'),
#   ('.', 'PUNCT', '.'),
#   ('Political', 'ADJ', 'JJ'),
#   ('violence', 'NOUN', 'NN'),
#   ('is', 'AUX', 'VBZ'),
#   ('an', 'DET', 'DT'),
#   ('attack', 'NOUN', 'NN'),
#   ('on', 'ADP', 'IN'),
#   ('everything', 'PRON', 'NN'),
#   ('we', 'PRON', 'PRP'),
#   ('cherish', 'VERB', 'VBP'),
#   ('as', 'ADP', 'IN'),
#   ('Americans', 'PROPN', 'NNPS'),
#   ('.', 'PUNCT', '.'),
#   ('It', 'PRON', 'PRP'),
#   ('can', 'AUX', 'MD'),
#   ('never', 'ADV', 'RB'),
#   ('be', 'AUX', 'VB'),
#   ('tolerated', 'VERB', 'VBN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('Now', 'ADV', 'RB'),
#   ('more', 'ADJ', 'JJR'),
#   ('than', 'ADP', 'IN'),
#   ('ever', 'ADV', 'RB'),
#   (',', 'PUNCT', ','),
#   ('we', 'PRON', 'PRP'),
#   ('must', 'AUX', 'MD'),
#   ('unify', 'VERB', 'VB'),
#   ('around', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('shared', 'VERB', 'VBN'),
#   ('values', 'NOUN', 'NNS'),
#   ('and', 'CCONJ', 'CC'),
#   ('rise', 'VERB', 'VB'),
#   ('above', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('partisan', 'ADJ', 'JJ'),
#   ('rancor', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('forge', 'VERB', 'VB'),
#   ('our', 'PRON', 'PRP$'),
#   ('common', 'ADJ', 'JJ'),
#   ('destiny', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('Four', 'NUM', 'CD'),
#   ('years', 'NOUN', 'NNS'),
#   ('ago', 'ADV', 'RB'),
#   (',', 'PUNCT', ','),
#   ('I', 'PRON', 'PRP'),
#   ('came', 'VERB', 'VBD'),
#   ('to', 'ADP', 'IN'),
#   ('Washington', 'PROPN', 'NNP'),
#   ('as', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('only', 'ADJ', 'JJ'),
#   ('true', 'ADJ', 'JJ'),
#   ('outsider', 'NOUN', 'NN'),
#   ('ever', 'ADV', 'RB'),
#   ('to', 'PART', 'TO'),
#   ('win', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('presidency', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('I', 'PRON', 'PRP'),
#   ('had', 'AUX', 'VBD'),
#   ('not', 'PART', 'RB'),
#   ('spent', 'VERB', 'VBN'),
#   ('my', 'PRON', 'PRP$'),
#   ('career', 'NOUN', 'NN'),
#   ('as', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('politician', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('but', 'CCONJ', 'CC'),
#   ('as', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('builder', 'NOUN', 'NN'),
#   ('looking', 'VERB', 'VBG'),
#   ('at', 'ADP', 'IN'),
#   ('open', 'ADJ', 'JJ'),
#   ('skylines', 'NOUN', 'NNS'),
#   ('and', 'CCONJ', 'CC'),
#   ('imagining', 'VERB', 'VBG'),
#   ('infinite', 'ADJ', 'JJ'),
#   ('possibilities', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('I', 'PRON', 'PRP'),
#   ('ran', 'VERB', 'VBD'),
#   ('for', 'ADP', 'IN'),
#   ('President', 'PROPN', 'NNP'),
#   ('because', 'SCONJ', 'IN'),
#   ('I', 'PRON', 'PRP'),
#   ('knew', 'VERB', 'VBD'),
#   ('there', 'PRON', 'EX'),
#   ('were', 'VERB', 'VBD'),
#   ('towering', 'VERB', 'VBG'),
#   ('new', 'ADJ', 'JJ'),
#   ('summits', 'NOUN', 'NNS'),
#   ('for', 'ADP', 'IN'),
#   ('America', 'PROPN', 'NNP'),
#   ('just', 'ADV', 'RB'),
#   ('waiting', 'VERB', 'VBG'),
#   ('to', 'PART', 'TO'),
#   ('be', 'AUX', 'VB'),
#   ('scaled', 'VERB', 'VBN'),
#   ('.', 'PUNCT', '.'),
#   ('I', 'PRON', 'PRP'),
#   ('knew', 'VERB', 'VBD'),
#   ('the', 'DET', 'DT'),
#   ('potential', 'NOUN', 'NN'),
#   ('for', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('nation', 'NOUN', 'NN'),
#   ('was', 'AUX', 'VBD'),
#   ('boundless', 'ADJ', 'JJ'),
#   ('as', 'ADV', 'RB'),
#   ('long', 'ADV', 'RB'),
#   ('as', 'SCONJ', 'IN'),
#   ('we', 'PRON', 'PRP'),
#   ('put', 'VERB', 'VBP'),
#   ('America', 'PROPN', 'NNP'),
#   ('first', 'ADV', 'RB'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('So', 'ADV', 'RB'),
#   ('I', 'PRON', 'PRP'),
#   ('left', 'VERB', 'VBD'),
#   ('behind', 'ADP', 'IN'),
#   ('my', 'PRON', 'PRP$'),
#   ('former', 'ADJ', 'JJ'),
#   ('life', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('stepped', 'VERB', 'VBD'),
#   ('into', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('very', 'ADV', 'RB'),
#   ('difficult', 'ADJ', 'JJ'),
#   ('arena', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('but', 'CCONJ', 'CC'),
#   ('an', 'DET', 'DT'),
#   ('arena', 'NOUN', 'NN'),
#   ('nevertheless', 'ADV', 'RB'),
#   (',', 'PUNCT', ','),
#   ('with', 'ADP', 'IN'),
#   ('all', 'DET', 'DT'),
#   ('sorts', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('potential', 'NOUN', 'NN'),
#   ('if', 'SCONJ', 'IN'),
#   ('properly', 'ADV', 'RB'),
#   ('done', 'VERB', 'VBN'),
#   ('.', 'PUNCT', '.'),
#   ('America', 'PROPN', 'NNP'),
#   ('had', 'AUX', 'VBD'),
#   ('given', 'VERB', 'VBN'),
#   ('me', 'PRON', 'PRP'),
#   ('so', 'ADV', 'RB'),
#   ('much', 'ADV', 'RB'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('I', 'PRON', 'PRP'),
#   ('wanted', 'VERB', 'VBD'),
#   ('to', 'PART', 'TO'),
#   ('give', 'VERB', 'VB'),
#   ('something', 'PRON', 'NN'),
#   ('back', 'ADV', 'RB'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('Together', 'ADV', 'RB'),
#   ('with', 'ADP', 'IN'),
#   ('millions', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('hardworking', 'VERB', 'VBG'),
#   ('patriots', 'NOUN', 'NNS'),
#   ('across', 'ADP', 'IN'),
#   ('this', 'DET', 'DT'),
#   ('land', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('we', 'PRON', 'PRP'),
#   ('built', 'VERB', 'VBD'),
#   ('the', 'DET', 'DT'),
#   ('greatest', 'ADJ', 'JJS'),
#   ('political', 'ADJ', 'JJ'),
#   ('movement', 'NOUN', 'NN'),
#   ('in', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('history', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('country', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('We', 'PRON', 'PRP'),
#   ('also', 'ADV', 'RB'),
#   ('built', 'VERB', 'VBD'),
#   ('the', 'DET', 'DT'),
#   ('greatest', 'ADJ', 'JJS'),
#   ('economy', 'NOUN', 'NN'),
#   ('in', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('history', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('world', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('It', 'PRON', 'PRP'),
#   ('was', 'AUX', 'VBD'),
#   ('about', 'ADP', 'IN'),
#   ('“', 'PUNCT', '``'),
#   ('America', 'PROPN', 'NNP'),
#   ('First', 'PROPN', 'NNP'),
#   ('”', 'PUNCT', "''"),
#   ('because', 'SCONJ', 'IN'),
#   ('we', 'PRON', 'PRP'),
#   ('all', 'PRON', 'DT'),
#   ('wanted', 'VERB', 'VBD'),
#   ('to', 'PART', 'TO'),
#   ('make', 'VERB', 'VB'),
#   ('America', 'PROPN', 'NNP'),
#   ('great', 'ADJ', 'JJ'),
#   ('again', 'ADV', 'RB'),
#   ('.', 'PUNCT', '.'),
#   ('We', 'PRON', 'PRP'),
#   ('restored', 'VERB', 'VBD'),
#   ('the', 'DET', 'DT'),
#   ('principle', 'NOUN', 'NN'),
#   ('that', 'SCONJ', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('nation', 'NOUN', 'NN'),
#   ('exists', 'VERB', 'VBZ'),
#   ('to', 'PART', 'TO'),
#   ('serve', 'VERB', 'VB'),
#   ('its', 'PRON', 'PRP$'),
#   ('citizens', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('Our', 'PRON', 'PRP$'),
#   ('agenda', 'NOUN', 'NN'),
#   ('was', 'AUX', 'VBD'),
#   ('not', 'PART', 'RB'),
#   ('about', 'ADV', 'RB'),
#   ('right', 'ADJ', 'JJ'),
#   ('or', 'CCONJ', 'CC'),
#   ('left', 'VERB', 'VBD'),
#   (',', 'PUNCT', ','),
#   ('it', 'PRON', 'PRP'),
#   ('was', 'AUX', 'VBD'),
#   ('n’t', 'PART', 'RB'),
#   ('about', 'ADP', 'IN'),
#   ('Republican', 'PROPN', 'NNP'),
#   ('or', 'CCONJ', 'CC'),
#   ('Democrat', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('but', 'CCONJ', 'CC'),
#   ('about', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('good', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('nation', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('that', 'PRON', 'DT'),
#   ('means', 'VERB', 'VBZ'),
#   ('the', 'DET', 'DT'),
#   ('whole', 'ADJ', 'JJ'),
#   ('nation', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('With', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('support', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('prayers', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('American', 'ADJ', 'JJ'),
#   ('people', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('we', 'PRON', 'PRP'),
#   ('achieved', 'VERB', 'VBD'),
#   ('more', 'ADJ', 'JJR'),
#   ('than', 'SCONJ', 'IN'),
#   ('anyone', 'PRON', 'NN'),
#   ('thought', 'VERB', 'VBD'),
#   ('possible', 'ADJ', 'JJ'),
#   ('.', 'PUNCT', '.'),
#   ('Nobody', 'PRON', 'NN'),
#   ('thought', 'VERB', 'VBD'),
#   ('we', 'PRON', 'PRP'),
#   ('could', 'AUX', 'MD'),
#   ('even', 'ADV', 'RB'),
#   ('come', 'VERB', 'VB'),
#   ('close', 'ADV', 'RB'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('We', 'PRON', 'PRP'),
#   ('passed', 'VERB', 'VBD'),
#   ('the', 'DET', 'DT'),
#   ('largest', 'ADJ', 'JJS'),
#   ('package', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('tax', 'NOUN', 'NN'),
#   ('cuts', 'NOUN', 'NNS'),
#   ('and', 'CCONJ', 'CC'),
#   ('reforms', 'NOUN', 'NNS'),
#   ('in', 'ADP', 'IN'),
#   ('American', 'ADJ', 'JJ'),
#   ('history', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('We', 'PRON', 'PRP'),
#   ('slashed', 'VERB', 'VBD'),
#   ('more', 'ADJ', 'JJR'),
#   ('job', 'NOUN', 'NN'),
#   ('-', 'PUNCT', 'HYPH'),
#   ('killing', 'VERB', 'VBG'),
#   ('regulations', 'NOUN', 'NNS'),
#   ('than', 'SCONJ', 'IN'),
#   ('any', 'DET', 'DT'),
#   ('administration', 'NOUN', 'NN'),
#   ('had', 'AUX', 'VBD'),
#   ('ever', 'ADV', 'RB'),
#   ('done', 'VERB', 'VBN'),
#   ('before', 'ADV', 'RB'),
#   ('.', 'PUNCT', '.'),
#   ('We', 'PRON', 'PRP'),
#   ('fixed', 'VERB', 'VBD'),
#   ('our', 'PRON', 'PRP$'),
#   ('broken', 'VERB', 'VBN'),
#   ('trade', 'NOUN', 'NN'),
#   ('deals', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('withdrew', 'VERB', 'VBD'),
#   ('from', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('horrible', 'ADJ', 'JJ'),
#   ('Trans', 'PROPN', 'NNP'),
#   ('-', 'PROPN', 'NNP'),
#   ('Pacific', 'PROPN', 'NNP'),
#   ('Partnership', 'PROPN', 'NNP'),
#   ('and', 'CCONJ', 'CC'),
#   ('the', 'DET', 'DT'),
#   ('impossible', 'ADJ', 'JJ'),
#   ('Paris', 'PROPN', 'NNP'),
#   ('Climate', 'PROPN', 'NNP'),
#   ('Accord', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('renegotiated', 'VERB', 'VBD'),
#   ('the', 'DET', 'DT'),
#   ('one', 'NUM', 'CD'),
#   ('-', 'PUNCT', 'HYPH'),
#   ('sided', 'VERB', 'VBN'),
#   ('South', 'PROPN', 'NNP'),
#   ('Korea', 'PROPN', 'NNP'),
#   ('deal', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('we', 'PRON', 'PRP'),
#   ('replaced', 'VERB', 'VBD'),
#   ('NAFTA', 'PROPN', 'NNP'),
#   ('with', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('groundbreaking', 'VERB', 'VBG'),
#   ('USMCA', 'PROPN', 'NNP'),
#   ('—', 'PUNCT', ':'),
#   ('that', 'PRON', 'WDT'),
#   ('’s', 'VERB', 'VBZ'),
#   ('Mexico', 'PROPN', 'NNP'),
#   ('and', 'CCONJ', 'CC'),
#   ('Canada', 'PROPN', 'NNP'),
#   ('—', 'PUNCT', ':'),
#   ('a', 'DET', 'DT'),
#   ('deal', 'NOUN', 'NN'),
#   ('that', 'PRON', 'WDT'),
#   ('’s', 'AUX', 'VBZ'),
#   ('worked', 'VERB', 'VBD'),
#   ('out', 'ADP', 'RP'),
#   ('very', 'ADV', 'RB'),
#   (',', 'PUNCT', ','),
#   ('very', 'ADV', 'RB'),
#   ('well', 'ADV', 'RB'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('Also', 'ADV', 'RB'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('very', 'ADV', 'RB'),
#   ('importantly', 'ADV', 'RB'),
#   (',', 'PUNCT', ','),
#   ('we', 'PRON', 'PRP'),
#   ('imposed', 'VERB', 'VBD'),
#   ('historic', 'ADJ', 'JJ'),
#   ('and', 'CCONJ', 'CC'),
#   ('monumental', 'ADJ', 'JJ'),
#   ('tariffs', 'NOUN', 'NNS'),
#   ('on', 'ADP', 'IN'),
#   ('China', 'PROPN', 'NNP'),
#   (';', 'PUNCT', ':'),
#   ('made', 'VERB', 'VBD'),
#   ('a', 'DET', 'DT'),
#   ('great', 'ADJ', 'JJ'),
#   ('new', 'ADJ', 'JJ'),
#   ('deal', 'NOUN', 'NN'),
#   ('with', 'ADP', 'IN'),
#   ('China', 'PROPN', 'NNP'),
#   ('.', 'PUNCT', '.'),
#   ('But', 'CCONJ', 'CC'),
#   ('before', 'SCONJ', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('ink', 'NOUN', 'NN'),
#   ('was', 'AUX', 'VBD'),
#   ('even', 'ADV', 'RB'),
#   ('dry', 'ADJ', 'JJ'),
#   (',', 'PUNCT', ','),
#   ('we', 'PRON', 'PRP'),
#   ('and', 'CCONJ', 'CC'),
#   ('the', 'DET', 'DT'),
#   ('whole', 'ADJ', 'JJ'),
#   ('world', 'NOUN', 'NN'),
#   ('got', 'AUX', 'VBD'),
#   ('hit', 'VERB', 'VBN'),
#   ('with', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('China', 'PROPN', 'NNP'),
#   ('virus', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('Our', 'PRON', 'PRP$'),
#   ('trade', 'NOUN', 'NN'),
#   ('relationship', 'NOUN', 'NN'),
#   ('was', 'AUX', 'VBD'),
#   ('rapidly', 'ADV', 'RB'),
#   ('changing', 'VERB', 'VBG'),
#   (',', 'PUNCT', ','),
#   ('billions', 'NOUN', 'NNS'),
#   ('and', 'CCONJ', 'CC'),
#   ('billions', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('dollars', 'NOUN', 'NNS'),
#   ('were', 'AUX', 'VBD'),
#   ('pouring', 'VERB', 'VBG'),
#   ('into', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('U.S.', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('but', 'CCONJ', 'CC'),
#   ('the', 'DET', 'DT'),
#   ('virus', 'NOUN', 'NN'),
#   ('forced', 'VERB', 'VBD'),
#   ('us', 'PRON', 'PRP'),
#   ('to', 'PART', 'TO'),
#   ('go', 'VERB', 'VB'),
#   ('in', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('different', 'ADJ', 'JJ'),
#   ('direction', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('The', 'DET', 'DT'),
#   ('whole', 'ADJ', 'JJ'),
#   ('world', 'NOUN', 'NN'),
#   ('suffered', 'VERB', 'VBD'),
#   (',', 'PUNCT', ','),
#   ('but', 'CCONJ', 'CC'),
#   ('America', 'PROPN', 'NNP'),
#   ('outperformed', 'VERB', 'VBD'),
#   ('other', 'ADJ', 'JJ'),
#   ('countries', 'NOUN', 'NNS'),
#   ('economically', 'ADV', 'RB'),
#   ('because', 'SCONJ', 'IN'),
#   ('of', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('incredible', 'ADJ', 'JJ'),
#   ('economy', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('the', 'DET', 'DT'),
#   ('economy', 'NOUN', 'NN'),
#   ('that', 'PRON', 'WDT'),
#   ('we', 'PRON', 'PRP'),
#   ('built', 'VERB', 'VBD'),
#   ('.', 'PUNCT', '.'),
#   ('Without', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('foundations', 'NOUN', 'NNS'),
#   ('and', 'CCONJ', 'CC'),
#   ('footings', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('it', 'PRON', 'PRP'),
#   ('would', 'AUX', 'MD'),
#   ('n’t', 'PART', 'RB'),
#   ('have', 'AUX', 'VB'),
#   ('worked', 'VERB', 'VBN'),
#   ('out', 'ADP', 'RP'),
#   ('this', 'DET', 'DT'),
#   ('way', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('We', 'PRON', 'PRP'),
#   ('would', 'AUX', 'MD'),
#   ('n’t', 'PART', 'RB'),
#   ('have', 'VERB', 'VB'),
#   ('some', 'PRON', 'DT'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('best', 'ADJ', 'JJS'),
#   ('numbers', 'NOUN', 'NNS'),
#   ('we', 'PRON', 'PRP'),
#   ('’ve', 'AUX', 'VBP'),
#   ('ever', 'ADV', 'RB'),
#   ('had', 'VERB', 'VBN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('We', 'PRON', 'PRP'),
#   ('also', 'ADV', 'RB'),
#   ('unlocked', 'VERB', 'VBD'),
#   ('our', 'PRON', 'PRP$'),
#   ('energy', 'NOUN', 'NN'),
#   ('resources', 'NOUN', 'NNS'),
#   ...],
#  [('Transcript', 'PROPN', 'NNP'),
#   ('\n', 'SPACE', '_SP'),
#   ('My', 'PRON', 'PRP$'),
#   ('fellow', 'ADJ', 'JJ'),
#   ('Americans', 'PROPN', 'NNPS'),
#   (',', 'PUNCT', ','),
#   ('\xa0\n', 'SPACE', '_SP'),
#   ('I', 'PRON', 'PRP'),
#   ('want', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('speak', 'VERB', 'VB'),
#   ('to', 'ADP', 'IN'),
#   ('you', 'PRON', 'PRP'),
#   ('tonight', 'NOUN', 'NN'),
#   ('about', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('troubling', 'ADJ', 'JJ'),
#   ('events', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('past', 'ADJ', 'JJ'),
#   ('week', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('As', 'SCONJ', 'IN'),
#   ('I', 'PRON', 'PRP'),
#   ('have', 'AUX', 'VBP'),
#   ('said', 'VERB', 'VBN'),
#   (',', 'PUNCT', ','),
#   ('the', 'DET', 'DT'),
#   ('incursion', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('US', 'PROPN', 'NNP'),
#   ('capitol', 'NOUN', 'NN'),
#   ('struck', 'VERB', 'VBD'),
#   ('at', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('very', 'ADJ', 'JJ'),
#   ('heart', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('republic', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('It', 'PRON', 'PRP'),
#   ('angered', 'VERB', 'VBD'),
#   ('and', 'CCONJ', 'CC'),
#   ('appalled', 'ADJ', 'JJ'),
#   ('millions', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('Americans', 'PROPN', 'NNPS'),
#   ('across', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('political', 'ADJ', 'JJ'),
#   ('spectrum', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0\n', 'SPACE', '_SP'),
#   ('I', 'PRON', 'PRP'),
#   ('want', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('be', 'AUX', 'VB'),
#   ('very', 'ADV', 'RB'),
#   ('clear', 'ADJ', 'JJ'),
#   ('.', 'PUNCT', '.'),
#   ('I', 'PRON', 'PRP'),
#   ('unequivocally', 'ADV', 'RB'),
#   ('condemn', 'VERB', 'VBP'),
#   ('the', 'DET', 'DT'),
#   ('violence', 'NOUN', 'NN'),
#   ('that', 'PRON', 'WDT'),
#   ('we', 'PRON', 'PRP'),
#   ('saw', 'VERB', 'VBD'),
#   ('last', 'ADJ', 'JJ'),
#   ('week', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('Violence', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('vandalism', 'NOUN', 'NN'),
#   ('have', 'VERB', 'VBP'),
#   ('absolutely', 'ADV', 'RB'),
#   ('no', 'DET', 'DT'),
#   ('place', 'NOUN', 'NN'),
#   ('in', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('country', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('no', 'DET', 'DT'),
#   ('place', 'NOUN', 'NN'),
#   ('in', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('movement', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('Making', 'VERB', 'VBG'),
#   ('America', 'PROPN', 'NNP'),
#   ('Great', 'PROPN', 'NNP'),
#   ('Again', 'ADV', 'RB'),
#   ('has', 'AUX', 'VBZ'),
#   ('always', 'ADV', 'RB'),
#   ('been', 'AUX', 'VBN'),
#   ('about', 'ADP', 'IN'),
#   ('defending', 'VERB', 'VBG'),
#   ('the', 'DET', 'DT'),
#   ('rule', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('law', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('supporting', 'VERB', 'VBG'),
#   ('the', 'DET', 'DT'),
#   ('men', 'NOUN', 'NNS'),
#   ('and', 'CCONJ', 'CC'),
#   ('women', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('law', 'NOUN', 'NN'),
#   ('enforcement', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('upholding', 'VERB', 'VBG'),
#   ('our', 'PRON', 'PRP$'),
#   ('nation', 'NOUN', 'NN'),
#   ("'s", 'PART', 'POS'),
#   ('most', 'ADV', 'RBS'),
#   ('sacred', 'ADJ', 'JJ'),
#   ('traditions', 'NOUN', 'NNS'),
#   ('and', 'CCONJ', 'CC'),
#   ('values', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0\n', 'SPACE', '_SP'),
#   ('Mob', 'PROPN', 'NNP'),
#   ('violence', 'NOUN', 'NN'),
#   ('goes', 'VERB', 'VBZ'),
#   ('against', 'ADP', 'IN'),
#   ('everything', 'PRON', 'NN'),
#   ('I', 'PRON', 'PRP'),
#   ('believe', 'VERB', 'VBP'),
#   ('in', 'ADP', 'IN'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('everything', 'PRON', 'NN'),
#   ('our', 'PRON', 'PRP$'),
#   ('movement', 'NOUN', 'NN'),
#   ('stands', 'VERB', 'VBZ'),
#   ('for', 'ADP', 'IN'),
#   ('.', 'PUNCT', '.'),
#   ('No', 'DET', 'DT'),
#   ('true', 'ADJ', 'JJ'),
#   ('supporter', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('mine', 'PRON', 'PRP'),
#   ('could', 'AUX', 'MD'),
#   ('ever', 'ADV', 'RB'),
#   ('endorse', 'VERB', 'VB'),
#   ('political', 'ADJ', 'JJ'),
#   ('violence', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('No', 'DET', 'DT'),
#   ('true', 'ADJ', 'JJ'),
#   ('supporter', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('mine', 'PRON', 'PRP'),
#   ('could', 'AUX', 'MD'),
#   ('ever', 'ADV', 'RB'),
#   ('disrespect', 'VERB', 'VB'),
#   ('law', 'NOUN', 'NN'),
#   ('enforcement', 'NOUN', 'NN'),
#   ('or', 'CCONJ', 'CC'),
#   ('our', 'PRON', 'PRP$'),
#   ('great', 'ADJ', 'JJ'),
#   ('American', 'ADJ', 'JJ'),
#   ('flag', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('No', 'DET', 'DT'),
#   ('true', 'ADJ', 'JJ'),
#   ('supporter', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('mine', 'PRON', 'PRP'),
#   ('could', 'AUX', 'MD'),
#   ('ever', 'ADV', 'RB'),
#   ('threaten', 'VERB', 'VB'),
#   ('or', 'CCONJ', 'CC'),
#   ('harass', 'VERB', 'VB'),
#   ('their', 'PRON', 'PRP$'),
#   ('fellow', 'ADJ', 'JJ'),
#   ('Americans', 'PROPN', 'NNPS'),
#   ('.', 'PUNCT', '.'),
#   ('If', 'SCONJ', 'IN'),
#   ('you', 'PRON', 'PRP'),
#   ('do', 'VERB', 'VBP'),
#   ('any', 'PRON', 'DT'),
#   ('of', 'ADP', 'IN'),
#   ('these', 'DET', 'DT'),
#   ('things', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('you', 'PRON', 'PRP'),
#   ('are', 'AUX', 'VBP'),
#   ('not', 'PART', 'RB'),
#   ('supporting', 'VERB', 'VBG'),
#   ('our', 'PRON', 'PRP$'),
#   ('movement', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('You', 'PRON', 'PRP'),
#   ('are', 'AUX', 'VBP'),
#   ('attacking', 'VERB', 'VBG'),
#   ('it', 'PRON', 'PRP'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('you', 'PRON', 'PRP'),
#   ('are', 'AUX', 'VBP'),
#   ('attacking', 'VERB', 'VBG'),
#   ('our', 'PRON', 'PRP$'),
#   ('country', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('We', 'PRON', 'PRP'),
#   ('can', 'AUX', 'MD'),
#   ('not', 'PART', 'RB'),
#   ('tolerate', 'VERB', 'VB'),
#   ('it', 'PRON', 'PRP'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0\n', 'SPACE', '_SP'),
#   ('Tragically', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('over', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('course', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('past', 'ADJ', 'JJ'),
#   ('year', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('made', 'VERB', 'VBN'),
#   ('so', 'ADV', 'RB'),
#   ('difficult', 'ADJ', 'JJ'),
#   ('because', 'SCONJ', 'IN'),
#   ('of', 'ADP', 'IN'),
#   ('covid-19', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('we', 'PRON', 'PRP'),
#   ('have', 'AUX', 'VBP'),
#   ('seen', 'VERB', 'VBN'),
#   ('political', 'ADJ', 'JJ'),
#   ('violence', 'NOUN', 'NN'),
#   ('spiral', 'NOUN', 'NN'),
#   ('out', 'ADP', 'IN'),
#   ('of', 'ADP', 'IN'),
#   ('control', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('We', 'PRON', 'PRP'),
#   ('have', 'AUX', 'VBP'),
#   ('seen', 'VERB', 'VBN'),
#   ('too', 'ADV', 'RB'),
#   ('many', 'ADJ', 'JJ'),
#   ('riots', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('too', 'ADV', 'RB'),
#   ('many', 'ADJ', 'JJ'),
#   ('mobs', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('too', 'ADV', 'RB'),
#   ('many', 'ADJ', 'JJ'),
#   ('acts', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('intimidation', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('destruction', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('It', 'PRON', 'PRP'),
#   ('must', 'AUX', 'MD'),
#   ('stop', 'VERB', 'VB'),
#   (',', 'PUNCT', ','),
#   ('whether', 'SCONJ', 'IN'),
#   ('you', 'PRON', 'PRP'),
#   ('are', 'AUX', 'VBP'),
#   ('on', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('right', 'NOUN', 'NN'),
#   ('or', 'CCONJ', 'CC'),
#   ('on', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('left', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('a', 'DET', 'DT'),
#   ('democrat', 'PROPN', 'NNP'),
#   ('or', 'CCONJ', 'CC'),
#   ('a', 'DET', 'DT'),
#   ('republican', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('there', 'PRON', 'EX'),
#   ('is', 'VERB', 'VBZ'),
#   ('never', 'ADV', 'RB'),
#   ('a', 'DET', 'DT'),
#   ('justification', 'NOUN', 'NN'),
#   ('for', 'ADP', 'IN'),
#   ('violence', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('No', 'DET', 'DT'),
#   ('excuses', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('No', 'DET', 'DT'),
#   ('exceptions', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0\n', 'SPACE', '_SP'),
#   ('America', 'PROPN', 'NNP'),
#   ('is', 'AUX', 'VBZ'),
#   ('a', 'DET', 'DT'),
#   ('nation', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('laws', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('Those', 'PRON', 'DT'),
#   ('who', 'PRON', 'WP'),
#   ('engaged', 'VERB', 'VBD'),
#   ('in', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('attacks', 'NOUN', 'NNS'),
#   ('last', 'ADJ', 'JJ'),
#   ('week', 'NOUN', 'NN'),
#   ('will', 'AUX', 'MD'),
#   ('be', 'AUX', 'VB'),
#   ('brought', 'VERB', 'VBN'),
#   ('to', 'ADP', 'IN'),
#   ('justice', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0\n', 'SPACE', '_SP'),
#   ('Now', 'ADV', 'RB'),
#   ('I', 'PRON', 'PRP'),
#   ('am', 'AUX', 'VBP'),
#   ('asking', 'VERB', 'VBG'),
#   ('everyone', 'PRON', 'NN'),
#   ('who', 'PRON', 'WP'),
#   ('has', 'AUX', 'VBZ'),
#   ('ever', 'ADV', 'RB'),
#   ('believed', 'VERB', 'VBN'),
#   ('in', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('agenda', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('to', 'PART', 'TO'),
#   ('be', 'AUX', 'VB'),
#   ('thinking', 'VERB', 'VBG'),
#   ('of', 'ADP', 'IN'),
#   ('ways', 'NOUN', 'NNS'),
#   ('to', 'PART', 'TO'),
#   ('ease', 'VERB', 'VB'),
#   ('tensions', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('calm', 'ADJ', 'JJ'),
#   ('tempers', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('help', 'VERB', 'VB'),
#   ('to', 'PART', 'TO'),
#   ('promote', 'VERB', 'VB'),
#   ('peace', 'NOUN', 'NN'),
#   ('in', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('country', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('There', 'PRON', 'EX'),
#   ('has', 'AUX', 'VBZ'),
#   ('been', 'AUX', 'VBN'),
#   ('reporting', 'VERB', 'VBG'),
#   ('that', 'SCONJ', 'IN'),
#   ('additional', 'ADJ', 'JJ'),
#   ('demonstrations', 'NOUN', 'NNS'),
#   ('are', 'AUX', 'VBP'),
#   ('being', 'AUX', 'VBG'),
#   ('planned', 'VERB', 'VBN'),
#   ('in', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('coming', 'VERB', 'VBG'),
#   ('days', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('both', 'CCONJ', 'CC'),
#   ('here', 'ADV', 'RB'),
#   ('in', 'ADP', 'IN'),
#   ('Washington', 'PROPN', 'NNP'),
#   ('and', 'CCONJ', 'CC'),
#   ('across', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('country', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('I', 'PRON', 'PRP'),
#   ('have', 'AUX', 'VBP'),
#   ('been', 'AUX', 'VBN'),
#   ('briefed', 'VERB', 'VBN'),
#   ('by', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('US', 'PROPN', 'NNP'),
#   ('secret', 'ADJ', 'JJ'),
#   ('service', 'NOUN', 'NN'),
#   ('on', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('potential', 'ADJ', 'JJ'),
#   ('threats', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0\n', 'SPACE', '_SP'),
#   ('Every', 'DET', 'DT'),
#   ('American', 'ADJ', 'JJ'),
#   ('deserves', 'VERB', 'VBZ'),
#   ('to', 'PART', 'TO'),
#   ('have', 'VERB', 'VB'),
#   ('their', 'PRON', 'PRP$'),
#   ('voice', 'NOUN', 'NN'),
#   ('heard', 'VERB', 'VBN'),
#   ('in', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('respectful', 'ADJ', 'JJ'),
#   ('and', 'CCONJ', 'CC'),
#   ('peaceful', 'ADJ', 'JJ'),
#   ('way', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('That', 'PRON', 'DT'),
#   ('is', 'AUX', 'VBZ'),
#   ('your', 'PRON', 'PRP$'),
#   ('First', 'PROPN', 'NNP'),
#   ('Amendment', 'PROPN', 'NNP'),
#   ('right', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('But', 'CCONJ', 'CC'),
#   ('I', 'PRON', 'PRP'),
#   ('can', 'AUX', 'MD'),
#   ('not', 'PART', 'RB'),
#   ('emphasize', 'VERB', 'VB'),
#   ('that', 'SCONJ', 'IN'),
#   ('there', 'PRON', 'EX'),
#   ('must', 'AUX', 'MD'),
#   ('be', 'AUX', 'VB'),
#   ('no', 'DET', 'DT'),
#   ('violence', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('no', 'DET', 'DT'),
#   ('lawbreaking', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('no', 'DET', 'DT'),
#   ('vandalism', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('any', 'DET', 'DT'),
#   ('kind', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('Everyone', 'PRON', 'NN'),
#   ('must', 'AUX', 'MD'),
#   ('follow', 'VERB', 'VB'),
#   ('our', 'PRON', 'PRP$'),
#   ('laws', 'NOUN', 'NNS'),
#   ('and', 'CCONJ', 'CC'),
#   ('obey', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('instructions', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('law', 'NOUN', 'NN'),
#   ('enforcement', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0\n', 'SPACE', '_SP'),
#   ('I', 'PRON', 'PRP'),
#   ('have', 'AUX', 'VBP'),
#   ('directed', 'VERB', 'VBN'),
#   ('federal', 'ADJ', 'JJ'),
#   ('agencies', 'NOUN', 'NNS'),
#   ('to', 'PART', 'TO'),
#   ('use', 'VERB', 'VB'),
#   ('all', 'DET', 'DT'),
#   ('necessary', 'ADJ', 'JJ'),
#   ('resources', 'NOUN', 'NNS'),
#   ('to', 'PART', 'TO'),
#   ('maintain', 'VERB', 'VB'),
#   ('order', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('In', 'ADP', 'IN'),
#   ('Washington', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('DC', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('we', 'PRON', 'PRP'),
#   ('are', 'AUX', 'VBP'),
#   ('bringing', 'VERB', 'VBG'),
#   ('in', 'ADP', 'RP'),
#   ('thousands', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('national', 'PROPN', 'NNP'),
#   ('guard', 'PROPN', 'NNP'),
#   ('members', 'NOUN', 'NNS'),
#   ('to', 'PART', 'TO'),
#   ('secure', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('city', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('ensure', 'VERB', 'VB'),
#   ('that', 'SCONJ', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('transition', 'NOUN', 'NN'),
#   ('can', 'AUX', 'MD'),
#   ('occur', 'VERB', 'VB'),
#   ('safely', 'ADV', 'RB'),
#   ('and', 'CCONJ', 'CC'),
#   ('without', 'ADP', 'IN'),
#   ('incident', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0\n', 'SPACE', '_SP'),
#   ('Like', 'ADP', 'IN'),
#   ('all', 'PRON', 'DT'),
#   ('of', 'ADP', 'IN'),
#   ('you', 'PRON', 'PRP'),
#   (',', 'PUNCT', ','),
#   ('I', 'PRON', 'PRP'),
#   ('was', 'AUX', 'VBD'),
#   ('shocked', 'ADJ', 'JJ'),
#   ('and', 'CCONJ', 'CC'),
#   ('deeply', 'ADV', 'RB'),
#   ('saddened', 'VERB', 'VBN'),
#   ('by', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('calamity', 'NOUN', 'NN'),
#   ('at', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('capitol', 'NOUN', 'NN'),
#   ('last', 'ADJ', 'JJ'),
#   ('week', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('I', 'PRON', 'PRP'),
#   ('want', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('thank', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('hundreds', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('millions', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('incredible', 'ADJ', 'JJ'),
#   ('American', 'ADJ', 'JJ'),
#   ('citizens', 'NOUN', 'NNS'),
#   ('who', 'PRON', 'WP'),
#   ('have', 'AUX', 'VBP'),
#   ('responded', 'VERB', 'VBN'),
#   ('to', 'ADP', 'IN'),
#   ('this', 'DET', 'DT'),
#   ('moment', 'NOUN', 'NN'),
#   ('with', 'ADP', 'IN'),
#   ('calm', 'ADJ', 'JJ'),
#   (',', 'PUNCT', ','),
#   ('moderation', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('grace', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('We', 'PRON', 'PRP'),
#   ('will', 'AUX', 'MD'),
#   ('get', 'VERB', 'VB'),
#   ('through', 'ADP', 'IN'),
#   ('this', 'DET', 'DT'),
#   ('challenge', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('just', 'ADV', 'RB'),
#   ('like', 'SCONJ', 'IN'),
#   ('we', 'PRON', 'PRP'),
#   ('always', 'ADV', 'RB'),
#   ('do', 'VERB', 'VBP'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0\n', 'SPACE', '_SP'),
#   ('I', 'PRON', 'PRP'),
#   ('also', 'ADV', 'RB'),
#   ('want', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('say', 'VERB', 'VB'),
#   ('a', 'DET', 'DT'),
#   ('few', 'ADJ', 'JJ'),
#   ('words', 'NOUN', 'NNS'),
#   ('about', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('unprecedented', 'ADJ', 'JJ'),
#   ('assault', 'NOUN', 'NN'),
#   ('on', 'ADP', 'IN'),
#   ('free', 'ADJ', 'JJ'),
#   ('speech', 'NOUN', 'NN'),
#   ('we', 'PRON', 'PRP'),
#   ('have', 'AUX', 'VBP'),
#   ('seen', 'VERB', 'VBN'),
#   ('in', 'ADP', 'IN'),
#   ('recent', 'ADJ', 'JJ'),
#   ('days', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('These', 'PRON', 'DT'),
#   ('are', 'AUX', 'VBP'),
#   ('tense', 'ADJ', 'JJ'),
#   ('and', 'CCONJ', 'CC'),
#   ('difficult', 'ADJ', 'JJ'),
#   ('times', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('The', 'DET', 'DT'),
#   ('efforts', 'NOUN', 'NNS'),
#   ('to', 'PART', 'TO'),
#   ('censor', 'VERB', 'VB'),
#   (',', 'PUNCT', ','),
#   ('cancel', 'VERB', 'VB'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('blacklist', 'VERB', 'VB'),
#   ('our', 'PRON', 'PRP$'),
#   ('fellow', 'ADJ', 'JJ'),
#   ('citizens', 'NOUN', 'NNS'),
#   ('are', 'AUX', 'VBP'),
#   ('wrong', 'ADJ', 'JJ'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('they', 'PRON', 'PRP'),
#   ('are', 'AUX', 'VBP'),
#   ('dangerous', 'ADJ', 'JJ'),
#   ('.', 'PUNCT', '.'),
#   ('What', 'PRON', 'WP'),
#   ('is', 'AUX', 'VBZ'),
#   ('needed', 'VERB', 'VBN'),
#   ('now', 'ADV', 'RB'),
#   ('is', 'AUX', 'VBZ'),
#   ('for', 'SCONJ', 'IN'),
#   ('us', 'PRON', 'PRP'),
#   ('to', 'PART', 'TO'),
#   ('listen', 'VERB', 'VB'),
#   ('to', 'ADP', 'IN'),
#   ('one', 'NUM', 'CD'),
#   ('another', 'DET', 'DT'),
#   (',', 'PUNCT', ','),
#   ('not', 'PART', 'RB'),
#   ('to', 'PART', 'TO'),
#   ('silence', 'VERB', 'VB'),
#   ('to', 'ADP', 'IN'),
#   ('one', 'NUM', 'CD'),
#   ('another', 'DET', 'DT'),
#   ('.', 'PUNCT', '.'),
#   ('All', 'PRON', 'DT'),
#   ('of', 'ADP', 'IN'),
#   ('us', 'PRON', 'PRP'),
#   ('can', 'AUX', 'MD'),
#   ('choose', 'VERB', 'VB'),
#   ('by', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('actions', 'NOUN', 'NNS'),
#   ('to', 'PART', 'TO'),
#   ('rise', 'VERB', 'VB'),
#   ('above', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('rancor', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('find', 'VERB', 'VB'),
#   ('common', 'ADJ', 'JJ'),
#   ('ground', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('shared', 'VERB', 'VBN'),
#   ('purpose', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('We', 'PRON', 'PRP'),
#   ('must', 'AUX', 'MD'),
#   ('focus', 'VERB', 'VB'),
#   ('on', 'ADP', 'IN'),
#   ('advancing', 'VERB', 'VBG'),
#   ('the', 'DET', 'DT'),
#   ('interests', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('whole', 'ADJ', 'JJ'),
#   ('nation', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('delivering', 'VERB', 'VBG'),
#   ('the', 'DET', 'DT'),
#   ('miracle', 'NOUN', 'NN'),
#   ('vaccines', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('defeating', 'VERB', 'VBG'),
#   ('the', 'DET', 'DT'),
#   ('pandemic', 'ADJ', 'JJ'),
#   (',', 'PUNCT', ','),
#   ('rebuilding', 'VERB', 'VBG'),
#   ('the', 'DET', 'DT'),
#   ('economy', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('protecting', 'VERB', 'VBG'),
#   ('our', 'PRON', 'PRP$'),
#   ('national', 'ADJ', 'JJ'),
#   ('security', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('upholding', 'VERB', 'VBG'),
#   ('the', 'DET', 'DT'),
#   ('rule', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('law', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0\n', 'SPACE', '_SP'),
#   ('Today', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('I', 'PRON', 'PRP'),
#   ('am', 'AUX', 'VBP'),
#   ('calling', 'VERB', 'VBG'),
#   ('on', 'ADP', 'IN'),
#   ('all', 'DET', 'DT'),
#   ('Americans', 'PROPN', 'NNPS'),
#   ('to', 'PART', 'TO'),
#   ('overcome', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('passions', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('moment', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('join', 'VERB', 'VB'),
#   ('together', 'ADV', 'RB'),
#   ('as', 'ADP', 'IN'),
#   ('one', 'NUM', 'CD'),
#   ('American', 'ADJ', 'JJ'),
#   ('people', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('Let', 'VERB', 'VB'),
#   ('us', 'PRON', 'PRP'),
#   ('choose', 'VERB', 'VB'),
#   ('to', 'PART', 'TO'),
#   ('move', 'VERB', 'VB'),
#   ('forward', 'ADV', 'RB'),
#   ('united', 'VERB', 'VBN'),
#   ('for', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('good', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('our', 'PRON', 'PRP$'),
#   ('families', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('our', 'PRON', 'PRP$'),
#   ('communities', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('our', 'PRON', 'PRP$'),
#   ('country', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('Thank', 'VERB', 'VBP'),
#   ('you', 'PRON', 'PRP'),
#   (',', 'PUNCT', ','),
#   ('God', 'PROPN', 'NNP'),
#   ('bless', 'VERB', 'VBP'),
#   ('you', 'PRON', 'PRP'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('God', 'PROPN', 'NNP'),
#   ('bless', 'VERB', 'VBP'),
#   ('America', 'PROPN', 'NNP'),
#   ('.', 'PUNCT', '.')],
#  [('Transcript', 'PROPN', 'NNP'),
#   ('\n', 'SPACE', '_SP'),
#   ('I', 'PRON', 'PRP'),
#   ('would', 'AUX', 'MD'),
#   ('like', 'VERB', 'VB'),
#   ('to', 'PART', 'TO'),
#   ('begin', 'VERB', 'VB'),
#   ('by', 'ADP', 'IN'),
#   ('addressing', 'VERB', 'VBG'),
#   ('the', 'DET', 'DT'),
#   ('heinous', 'ADJ', 'JJ'),
#   ('attack', 'NOUN', 'NN'),
#   ('on', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('United', 'PROPN', 'NNP'),
#   ('States', 'PROPN', 'NNP'),
#   ('Capitol', 'PROPN', 'NNP'),
#   ('.', 'PUNCT', '.'),
#   ('Like', 'ADP', 'IN'),
#   ('all', 'DET', 'DT'),
#   ('Americans', 'PROPN', 'NNPS'),
#   (',', 'PUNCT', ','),
#   ('I', 'PRON', 'PRP'),
#   ('am', 'AUX', 'VBP'),
#   ('outraged', 'ADJ', 'JJ'),
#   ('by', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('violence', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('lawlessness', 'ADJ', 'JJR'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('mayhem', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('I', 'PRON', 'PRP'),
#   ('immediately', 'ADV', 'RB'),
#   ('deployed', 'VERB', 'VBD'),
#   ('the', 'DET', 'DT'),
#   ('National', 'PROPN', 'NNP'),
#   ('Guard', 'PROPN', 'NNP'),
#   ('and', 'CCONJ', 'CC'),
#   ('federal', 'ADJ', 'JJ'),
#   ('law', 'NOUN', 'NN'),
#   ('enforcement', 'NOUN', 'NN'),
#   ('to', 'PART', 'TO'),
#   ('secure', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('building', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('expel', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('intruders', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0\n', 'SPACE', '_SP'),
#   ('America', 'PROPN', 'NNP'),
#   ('is', 'AUX', 'VBZ'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('must', 'AUX', 'MD'),
#   ('always', 'ADV', 'RB'),
#   ('be', 'AUX', 'VB'),
#   (',', 'PUNCT', ','),
#   ('a', 'DET', 'DT'),
#   ('nation', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('law', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('order', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('The', 'DET', 'DT'),
#   ('demonstrators', 'NOUN', 'NNS'),
#   ('who', 'PRON', 'WP'),
#   ('infiltrated', 'VERB', 'VBD'),
#   ('the', 'DET', 'DT'),
#   ('Capitol', 'PROPN', 'NNP'),
#   ('have', 'AUX', 'VBP'),
#   ('defiled', 'VERB', 'VBN'),
#   ('the', 'DET', 'DT'),
#   ('seat', 'NOUN', 'NN'),
# ...
#   ('the', 'DET', 'DT'),
#   ('compound', 'NOUN', 'NN'),
#   ('for', 'ADP', 'IN'),
#   ('approximately', 'ADV', 'RB'),
#   ('2', 'NUM', 'CD'),
#   ('hours', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('after', 'SCONJ', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('mission', 'NOUN', 'NN'),
#   ('was', 'AUX', 'VBD'),
#   ('accomplished', 'VERB', 'VBN'),
#   ('we', 'PRON', 'PRP'),
#   ('took', 'VERB', 'VBD'),
#   ('highly', 'ADV', 'RB'),
#   ('sensitive', 'ADJ', 'JJ'),
#   ('material', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('information', 'NOUN', 'NN'),
#   ('from', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('raid', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\r\n', 'SPACE', '_SP'),
#   ('Baghdadi', 'PROPN', 'NNP'),
#   ('’s', 'PART', 'POS'),
#   ('demise', 'NOUN', 'NN'),
#   ('demonstrates', 'VERB', 'VBZ'),
#   ('America', 'PROPN', 'NNP'),
#   ('’s', 'PART', 'POS'),
#   ('relentless', 'ADJ', 'JJ'),
#   ('pursuit', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('terrorist', 'ADJ', 'JJ'),
#   ('leaders', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('our', 'PRON', 'PRP$'),
#   ('commitment', 'NOUN', 'NN'),
#   ('to', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('enduring', 'ADJ', 'JJ'),
#   ('and', 'CCONJ', 'CC'),
#   ('total', 'ADJ', 'JJ'),
#   ('defeat', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('ISIS', 'PROPN', 'NNP'),
#   ('!', 'PUNCT', '.'),
#   ('\r\n', 'SPACE', '_SP'),
#   ('The', 'DET', 'DT'),
#   ('reach', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('America', 'PROPN', 'NNP'),
#   ('is', 'AUX', 'VBZ'),
#   ('long', 'ADJ', 'JJ'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0 ', 'SPACE', '_SP'),
#   ('As', 'SCONJ', 'IN'),
#   ('you', 'PRON', 'PRP'),
#   ('know', 'VERB', 'VBP'),
#   (',', 'PUNCT', ','),
#   ('last', 'ADJ', 'JJ'),
#   ('month', 'NOUN', 'NN'),
#   ('we', 'PRON', 'PRP'),
#   ('announced', 'VERB', 'VBD'),
#   ('that', 'SCONJ', 'IN'),
#   ('we', 'PRON', 'PRP'),
#   ('recently', 'ADV', 'RB'),
#   ('killed', 'VERB', 'VBD'),
#   ('Hamza', 'PROPN', 'NNP'),
#   ('Bin', 'PROPN', 'NNP'),
#   ('Laden', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('the', 'DET', 'DT'),
#   ('very', 'ADV', 'RB'),
#   ('violent', 'ADJ', 'JJ'),
#   ('son', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('Osama', 'PROPN', 'NNP'),
#   ('Bin', 'PROPN', 'NNP'),
#   ('Laden', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('who', 'PRON', 'WP'),
#   ('was', 'AUX', 'VBD'),
#   ('saying', 'VERB', 'VBG'),
#   ('very', 'ADV', 'RB'),
#   ('bad', 'ADJ', 'JJ'),
#   ('things', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('He', 'PRON', 'PRP'),
#   ('was', 'AUX', 'VBD'),
#   ('the', 'DET', 'DT'),
#   ('heir', 'NOUN', 'NN'),
#   ('apparent', 'ADJ', 'JJ'),
#   ('to', 'ADP', 'IN'),
#   ('Al', 'PROPN', 'NNP'),
#   ('Qaeda', 'PROPN', 'NNP'),
#   ('.', 'PUNCT', '.'),
#   ('Terrorists', 'NOUN', 'NNS'),
#   ('who', 'PRON', 'WP'),
#   ('oppress', 'VERB', 'VBP'),
#   ('and', 'CCONJ', 'CC'),
#   ('murder', 'NOUN', 'NN'),
#   ('innocent', 'ADJ', 'JJ'),
#   ('people', 'NOUN', 'NNS'),
#   ('should', 'AUX', 'MD'),
#   ('never', 'ADV', 'RB'),
#   ('sleep', 'VERB', 'VB'),
#   ('soundly', 'ADV', 'RB'),
#   (',', 'PUNCT', ','),
#   ('knowing', 'VERB', 'VBG'),
#   ('that', 'SCONJ', 'IN'),
#   ('we', 'PRON', 'PRP'),
#   ('will', 'AUX', 'MD'),
#   ('completely', 'ADV', 'RB'),
#   ('destroy', 'VERB', 'VB'),
#   ('them', 'PRON', 'PRP'),
#   ('.', 'PUNCT', '.'),
#   ('These', 'DET', 'DT'),
#   ('savage', 'NOUN', 'NN'),
#   ('monsters', 'NOUN', 'NNS'),
#   ('will', 'AUX', 'MD'),
#   ('not', 'PART', 'RB'),
#   ('escape', 'VERB', 'VB'),
#   ('their', 'PRON', 'PRP$'),
#   ('fate', 'NOUN', 'NN'),
#   ('–', 'PUNCT', ':'),
#   ('and', 'CCONJ', 'CC'),
#   ('they', 'PRON', 'PRP'),
#   ('will', 'AUX', 'MD'),
#   ('not', 'PART', 'RB'),
#   ('escape', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('final', 'ADJ', 'JJ'),
#   ('judgement', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('God', 'PROPN', 'NNP'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('Baghdadi', 'PROPN', 'NNP'),
#   ('has', 'AUX', 'VBZ'),
#   ('been', 'AUX', 'VBN'),
#   ('on', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('run', 'NOUN', 'NN'),
#   ('for', 'ADP', 'IN'),
#   ('many', 'ADJ', 'JJ'),
#   ('years', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('long', 'ADV', 'RB'),
#   ('before', 'SCONJ', 'IN'),
#   ('I', 'PRON', 'PRP'),
#   ('took', 'VERB', 'VBD'),
#   ('office', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('At', 'ADP', 'IN'),
#   ('my', 'PRON', 'PRP$'),
#   ('direction', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('as', 'ADP', 'IN'),
#   ('Commander', 'PROPN', 'NNP'),
#   ('-', 'PUNCT', 'HYPH'),
#   ('in', 'ADP', 'IN'),
#   ('-', 'PUNCT', 'HYPH'),
#   ('Chief', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('the', 'DET', 'DT'),
#   ('United', 'PROPN', 'NNP'),
#   ('States', 'PROPN', 'NNP'),
#   ('obliterated', 'VERB', 'VBD'),
#   ('his', 'PRON', 'PRP$'),
#   ('‘', 'PUNCT', '``'),
#   ('caliphate', 'NOUN', 'NN'),
#   ('’', 'PUNCT', "''"),
#   ('in', 'ADP', 'IN'),
#   ('March', 'PROPN', 'NNP'),
#   ('of', 'ADP', 'IN'),
#   ('this', 'DET', 'DT'),
#   ('year', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0 ', 'SPACE', '_SP'),
#   ('Today', 'NOUN', 'NN'),
#   ('’s', 'PART', 'POS'),
#   ('events', 'NOUN', 'NNS'),
#   ('are', 'AUX', 'VBP'),
#   ('another', 'DET', 'DT'),
#   ('reminder', 'NOUN', 'NN'),
#   ('that', 'SCONJ', 'IN'),
#   ('we', 'PRON', 'PRP'),
#   ('will', 'AUX', 'MD'),
#   ('continue', 'VERB', 'VB'),
#   ('to', 'PART', 'TO'),
#   ('pursue', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('remaining', 'VERB', 'VBG'),
#   ('ISIS', 'PROPN', 'NNP'),
#   ('terrorists', 'NOUN', 'NNS'),
#   ('to', 'ADP', 'IN'),
#   ('their', 'PRON', 'PRP$'),
#   ('brutal', 'ADJ', 'JJ'),
#   ('end', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('Baghdadi', 'PROPN', 'NNP'),
#   ('and', 'CCONJ', 'CC'),
#   ('the', 'DET', 'DT'),
#   ('losers', 'NOUN', 'NNS'),
#   ('who', 'PRON', 'WP'),
#   ('worked', 'VERB', 'VBD'),
#   ('with', 'ADP', 'IN'),
#   ('him', 'PRON', 'PRP'),
#   ('–', 'PUNCT', ':'),
#   ('in', 'ADP', 'IN'),
#   ('some', 'DET', 'DT'),
#   ('cases', 'NOUN', 'NNS'),
#   ('people', 'NOUN', 'NNS'),
#   ('who', 'PRON', 'WP'),
#   ('had', 'VERB', 'VBD'),
#   ('no', 'DET', 'DT'),
#   ('idea', 'NOUN', 'NN'),
#   ('what', 'PRON', 'WP'),
#   ('they', 'PRON', 'PRP'),
#   ('were', 'AUX', 'VBD'),
#   ('getting', 'VERB', 'VBG'),
#   ('into', 'ADP', 'IN'),
#   ('and', 'CCONJ', 'CC'),
#   ('how', 'SCONJ', 'WRB'),
#   ('dangerous', 'ADJ', 'JJ'),
#   ('and', 'CCONJ', 'CC'),
#   ('unglamorous', 'ADJ', 'JJ'),
#   ('it', 'PRON', 'PRP'),
#   ('was', 'AUX', 'VBD'),
#   ('–', 'PUNCT', ':'),
#   ('killed', 'VERB', 'VBD'),
#   ('many', 'ADJ', 'JJ'),
#   ('people', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0 ', 'SPACE', '_SP'),
#   ('Their', 'PRON', 'PRP$'),
#   ('murder', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('innocent', 'ADJ', 'JJ'),
#   ('Americans', 'PROPN', 'NNPS'),
#   ('Jim', 'PROPN', 'NNP'),
#   ('Foley', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('Steven', 'PROPN', 'NNP'),
#   ('Sotloff', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('Peter', 'PROPN', 'NNP'),
#   ('Kassig', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('Kayla', 'PROPN', 'NNP'),
#   ('Mueller', 'PROPN', 'NNP'),
#   ('were', 'AUX', 'VBD'),
#   ('especially', 'ADV', 'RB'),
#   ('heinous', 'ADJ', 'JJ'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0 ', 'SPACE', '_SP'),
#   ('The', 'DET', 'DT'),
#   ('shocking', 'ADJ', 'JJ'),
#   ('publicized', 'VERB', 'VBN'),
#   ('murder', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('Jordanian', 'ADJ', 'JJ'),
#   ('pilot', 'NOUN', 'NN'),
#   ('who', 'PRON', 'WP'),
#   ('was', 'AUX', 'VBD'),
#   ('burned', 'VERB', 'VBN'),
#   ('alive', 'ADJ', 'JJ'),
#   ('in', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('cage', 'NOUN', 'NN'),
#   ('for', 'SCONJ', 'IN'),
#   ('all', 'PRON', 'DT'),
#   ('to', 'PART', 'TO'),
#   ('see', 'VERB', 'VB'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('the', 'DET', 'DT'),
#   ('execution', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('Christians', 'PROPN', 'NNPS'),
#   ('in', 'ADP', 'IN'),
#   ('Libya', 'PROPN', 'NNP'),
#   ('and', 'CCONJ', 'CC'),
#   ('Egypt', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('as', 'ADV', 'RB'),
#   ('well', 'ADV', 'RB'),
#   ('as', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('genocidal', 'ADJ', 'JJ'),
#   ('mass', 'ADJ', 'JJ'),
#   ('murder', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('Yazidis', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('rank', 'NOUN', 'NN'),
#   ('ISIS', 'PROPN', 'NNP'),
#   ('among', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('most', 'ADV', 'RBS'),
#   ('depraved', 'ADJ', 'JJ'),
#   ('organizations', 'NOUN', 'NNS'),
#   ('in', 'ADP', 'IN'),
#   ('history', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('The', 'DET', 'DT'),
#   ('forced', 'VERB', 'VBN'),
#   ('religious', 'ADJ', 'JJ'),
#   ('conversions', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('the', 'DET', 'DT'),
#   ('orange', 'ADJ', 'JJ'),
#   ('suits', 'NOUN', 'NNS'),
#   ('prior', 'ADV', 'RB'),
#   ('to', 'ADP', 'IN'),
#   ('many', 'ADJ', 'JJ'),
#   ('beheadings', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('all', 'PRON', 'DT'),
#   ('of', 'ADP', 'IN'),
#   ('which', 'PRON', 'WDT'),
#   ('were', 'AUX', 'VBD'),
#   ('openly', 'ADV', 'RB'),
#   ('displayed', 'VERB', 'VBN'),
#   ('for', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('world', 'NOUN', 'NN'),
#   ('–', 'PUNCT', ':'),
#   ('this', 'PRON', 'DT'),
#   ('was', 'AUX', 'VBD'),
#   ('all', 'PRON', 'DT'),
#   ('Abu', 'PROPN', 'NNP'),
#   ('Bakr', 'PROPN', 'NNP'),
#   ('al', 'PROPN', 'NNP'),
#   ('-', 'PUNCT', 'HYPH'),
#   ('Baghdadi', 'PROPN', 'NNP'),
#   ('’s', 'PART', 'POS'),
#   ('work', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0 ', 'SPACE', '_SP'),
#   ('He', 'PRON', 'PRP'),
#   ('was', 'AUX', 'VBD'),
#   ('vicious', 'ADJ', 'JJ'),
#   ('and', 'CCONJ', 'CC'),
#   ('violent', 'ADJ', 'JJ'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('he', 'PRON', 'PRP'),
#   ('died', 'VERB', 'VBD'),
#   ('in', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('vicious', 'ADJ', 'JJ'),
#   ('and', 'CCONJ', 'CC'),
#   ('violent', 'ADJ', 'JJ'),
#   ('way', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('as', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('coward', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('running', 'VERB', 'VBG'),
#   ('and', 'CCONJ', 'CC'),
#   ('crying', 'VERB', 'VBG'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0 ', 'SPACE', '_SP'),
#   ('This', 'DET', 'DT'),
#   ('raid', 'NOUN', 'NN'),
#   ('was', 'AUX', 'VBD'),
#   ('impeccable', 'ADJ', 'JJ'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('could', 'AUX', 'MD'),
#   ('only', 'ADV', 'RB'),
#   ('have', 'AUX', 'VB'),
#   ('taken', 'VERB', 'VBN'),
#   ('place', 'NOUN', 'NN'),
#   ('with', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('acknowledgement', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('help', 'NOUN', 'NN'),
#   ('of', 'ADP', 'IN'),
#   ('certain', 'ADJ', 'JJ'),
#   ('other', 'ADJ', 'JJ'),
#   ('nations', 'NOUN', 'NNS'),
#   ('and', 'CCONJ', 'CC'),
#   ('people', 'NOUN', 'NNS'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('I', 'PRON', 'PRP'),
#   ('want', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('thank', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('nations', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('Russia', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('Turkey', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('Syria', 'PROPN', 'NNP'),
#   ('and', 'CCONJ', 'CC'),
#   ('Iraq', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('I', 'PRON', 'PRP'),
#   ('also', 'ADV', 'RB'),
#   ('want', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('thank', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('Syrian', 'ADJ', 'JJ'),
#   ('Kurds', 'PROPN', 'NNPS'),
#   ('for', 'ADP', 'IN'),
#   ('certain', 'ADJ', 'JJ'),
#   ('support', 'NOUN', 'NN'),
#   ('they', 'PRON', 'PRP'),
#   ('were', 'AUX', 'VBD'),
#   ('able', 'ADJ', 'JJ'),
#   ('to', 'PART', 'TO'),
#   ('give', 'VERB', 'VB'),
#   ('us', 'PRON', 'PRP'),
#   ('.', 'PUNCT', '.'),
#   ('Thank', 'VERB', 'VBP'),
#   ('you', 'PRON', 'PRP'),
#   ('as', 'ADV', 'RB'),
#   ('well', 'ADV', 'RB'),
#   ('to', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('great', 'ADJ', 'JJ'),
#   ('intelligence', 'NOUN', 'NN'),
#   ('professionals', 'NOUN', 'NNS'),
#   ('who', 'PRON', 'WP'),
#   ('helped', 'VERB', 'VBD'),
#   ('make', 'VERB', 'VB'),
#   ('this', 'DET', 'DT'),
#   ('very', 'ADV', 'RB'),
#   ('successful', 'ADJ', 'JJ'),
#   ('journey', 'NOUN', 'NN'),
#   ('possible', 'ADJ', 'JJ'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('I', 'PRON', 'PRP'),
#   ('want', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('thank', 'VERB', 'VB'),
#   ('the', 'DET', 'DT'),
#   ('soldiers', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('sailors', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('airmen', 'NOUN', 'NNS'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('marines', 'NOUN', 'NNS'),
#   ('involved', 'VERB', 'VBN'),
#   ('in', 'ADP', 'IN'),
#   ('last', 'ADJ', 'JJ'),
#   ('night', 'NOUN', 'NN'),
#   ('’s', 'PART', 'POS'),
#   ('operation', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0 ', 'SPACE', '_SP'),
#   ('You', 'PRON', 'PRP'),
#   ('are', 'AUX', 'VBP'),
#   ('the', 'DET', 'DT'),
#   ('very', 'ADV', 'RB'),
#   ('best', 'ADJ', 'JJS'),
#   ('there', 'PRON', 'EX'),
#   ('is', 'VERB', 'VBZ'),
#   ('anywhere', 'ADV', 'RB'),
#   ('in', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('world', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0 ', 'SPACE', '_SP'),
#   ('I', 'PRON', 'PRP'),
#   ('want', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('thank', 'VERB', 'VB'),
#   ('General', 'PROPN', 'NNP'),
#   ('Mark', 'PROPN', 'NNP'),
#   ('Milley', 'PROPN', 'NNP'),
#   ('and', 'CCONJ', 'CC'),
#   ('our', 'PRON', 'PRP$'),
#   ('Joint', 'PROPN', 'NNP'),
#   ('Chiefs', 'PROPN', 'NNPS'),
#   ('of', 'ADP', 'IN'),
#   ('Staff', 'PROPN', 'NNP'),
#   (',', 'PUNCT', ','),
#   ('and', 'CCONJ', 'CC'),
#   ('I', 'PRON', 'PRP'),
#   ('also', 'ADV', 'RB'),
#   ('want', 'VERB', 'VBP'),
#   ('to', 'PART', 'TO'),
#   ('thank', 'VERB', 'VB'),
#   ('our', 'PRON', 'PRP$'),
#   ('professionals', 'NOUN', 'NNS'),
#   ('who', 'PRON', 'WP'),
#   ('work', 'VERB', 'VBP'),
#   ('in', 'ADP', 'IN'),
#   ('other', 'ADJ', 'JJ'),
#   ('agencies', 'NOUN', 'NNS'),
#   ('of', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('United', 'PROPN', 'NNP'),
#   ('States', 'PROPN', 'NNP'),
#   ('government', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('were', 'AUX', 'VBD'),
#   ('critical', 'ADJ', 'JJ'),
#   ('to', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('mission', 'NOUN', 'NN'),
#   ('’s', 'PART', 'POS'),
#   ('success', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('Last', 'ADJ', 'JJ'),
#   ('night', 'NOUN', 'NN'),
#   ('was', 'AUX', 'VBD'),
#   ('a', 'DET', 'DT'),
#   ('great', 'ADJ', 'JJ'),
#   ('night', 'NOUN', 'NN'),
#   ('for', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('United', 'PROPN', 'NNP'),
#   ('States', 'PROPN', 'NNP'),
#   ('and', 'CCONJ', 'CC'),
#   ('for', 'ADP', 'IN'),
#   ('the', 'DET', 'DT'),
#   ('World', 'PROPN', 'NNP'),
#   ('.', 'PUNCT', '.'),
#   ('A', 'DET', 'DT'),
#   ('brutal', 'ADJ', 'JJ'),
#   ('killer', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('one', 'NUM', 'CD'),
#   ('who', 'PRON', 'WP'),
#   ('has', 'AUX', 'VBZ'),
#   ('caused', 'VERB', 'VBN'),
#   ('so', 'ADV', 'RB'),
#   ('much', 'ADJ', 'JJ'),
#   ('hardship', 'NOUN', 'NN'),
#   ('and', 'CCONJ', 'CC'),
#   ('death', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('was', 'AUX', 'VBD'),
#   ('violently', 'ADV', 'RB'),
#   ('eliminated', 'VERB', 'VBN'),
#   ('–', 'PUNCT', ':'),
#   ('he', 'PRON', 'PRP'),
#   ('will', 'AUX', 'MD'),
#   ('never', 'ADV', 'RB'),
#   ('again', 'ADV', 'RB'),
#   ('harm', 'VERB', 'VB'),
#   ('another', 'DET', 'DT'),
#   ('innocent', 'ADJ', 'JJ'),
#   ('man', 'NOUN', 'NN'),
#   (',', 'PUNCT', ','),
#   ('woman', 'NOUN', 'NN'),
#   ('or', 'CCONJ', 'CC'),
#   ('child', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0 ', 'SPACE', '_SP'),
#   ('He', 'PRON', 'PRP'),
#   ('died', 'VERB', 'VBD'),
#   ('like', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('dog', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0 ', 'SPACE', '_SP'),
#   ('He', 'PRON', 'PRP'),
#   ('died', 'VERB', 'VBD'),
#   ('like', 'ADP', 'IN'),
#   ('a', 'DET', 'DT'),
#   ('coward', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\xa0 ', 'SPACE', '_SP'),
#   ('The', 'DET', 'DT'),
#   ('world', 'NOUN', 'NN'),
#   ('is', 'AUX', 'VBZ'),
#   ('now', 'ADV', 'RB'),
#   ('a', 'DET', 'DT'),
#   ('much', 'ADV', 'RB'),
#   ('safer', 'ADJ', 'JJR'),
#   ('place', 'NOUN', 'NN'),
#   ('.', 'PUNCT', '.'),
#   ('\n', 'SPACE', '_SP'),
#   ('God', 'PROPN', 'NNP'),
#   ('bless', 'VERB', 'VBP'),
#   ('the', 'DET', 'DT'),
#   ('United', 'PROPN', 'NNP'),
#   ('States', 'PROPN', 'NNP'),
#   ('of', 'ADP', 'IN'),
#   ('America', 'PROPN', 'NNP'),
#   ('!', 'PUNCT', '.')]]

# %%
data['Proper_Nouns'] = data['Doc'].apply(lambda doc: [token.text for token in doc if token.pos_ == 'PROPN'])

# %%
list(data.loc[[3, 5], 'Proper_Nouns'])
# Out:
# [['Transcript'],
#  ['Transcript',
#   'PRESIDENT',
#   'America',
#   'United',
#   'States',
#   'Constitution',
#   'Constitution',
#   'Republic',
#   'President',
#   'Supreme',
#   'Court',
#   'October',
#   'First',
#   'Lady',
#   'White',
#   'House',
#   'United',
#   'States',
#   'Supreme',
#   'Court',
#   'Justice',
#   'Amy',
#   'Coney',
#   'Barrett',
#   'Justice',
#   'Barrett',
#   'Court',
#   'Americans',
#   'Justice',
#   'Clarence',
#   'Thomas',
#   'Senate',
#   'Majority',
#   'Leader',
#   'Mitch',
#   'McConnell',
#   'Mitch',
#   'Senate',
#   'Judiciary',
#   'Chairman',
#   'Lindsey',
#   'Graham',
#   'Lindsey',
#   'Senators',
#   'Marsha',
#   'Blackburn',
#   'Mike',
#   'Braun',
#   'Bill',
#   'Cassidy',
#   'Kevin',
#   'Cramer',
#   'Ted',
#   'Cruz',
#   'Steve',
#   'Daines',
#   'Ron',
#   'Johnson',
#   'James',
#   'Lankford',
#   'Mike',
#   'Lee',
#   'Martha',
#   'McSally',
#   'Vice',
#   'President',
#   'Mike',
#   'Pence',
#   'Mike',
#   'White',
#   'House',
#   'Counsel',
#   'Pat',
#   'Cipollone',
#   'Pat',
#   '.',
#   'Justice',
#   'Barrett',
#   'Jesse',
#   'Jesse',
#   'Indiana',
#   'Barrett',
#   'America',
#   'Justice',
#   'Barrett',
#   'Justice',
#   'Ruth',
#   'Bader',
#   'Ginsburg',
#   'Justice',
#   'Barrett',
#   'Supreme',
#   'Court',
#   'Justice',
#   'Barrett',
#   'Justice',
#   'Barrett',
#   'Notre',
#   'Dame',
#   'Law',
#   'School',
#   'Justice',
#   'Antonin',
#   'Scalia',
#   'Notre',
#   'Dame',
#   'Law',
#   'School',
#   'U.S.',
#   'Circuit',
#   'Court',
#   'Appeals',
#   '7th',
#   'Circuit',
#   'Justice',
#   'Barrett',
#   'Constitution',
#   'America',
#   'America',
#   'Constitution',
#   'America',
#   'American',
#   'Revolution',
#   'White',
#   'House',
#   'Americans',
#   'Civil',
#   'War',
#   'Civil',
#   'Rights',
#   'Americans',
#   'Justice',
#   'Barrett',
#   'Constitution',
#   'God',
#   'America',
#   'America',
#   'America',
#   'Justice',
#   'Thomas',
#   'Oath',
#   'Judicial',
#   'Oath',
#   'JUSTICE',
#   'President',
#   'Trump',
#   'Associate',
#   'Justice',
#   'United',
#   'States',
#   'Supreme',
#   'Court',
#   'Senate',
#   'Leader',
#   'McConnell',
#   'Chairman',
#   'Graham',
#   'White',
#   'House',
#   'Department',
#   'Justice',
#   'Jesse',
#   'Jesse',
#   'Senate',
#   'Senate',
#   'Judiciary',
#   'Committee',
#   'United',
#   'States',
#   'Senate',
#   'Congress',
#   'President',
#   'Judicial',
#   'Oath',
#   'Americans',
#   'Constitution',
#   'Constitution',
#   'Democratic',
#   'Republic']]

# %% [markdown]
# Saving the annotated corpus in csv file

# %%
annotated_corpus_path = 'annotated_corpus.csv'
data.to_csv(annotated_corpus_path, index=False, encoding='utf-8')

print(f"Annotated corpus has been saved to {annotated_corpus_path}")
# Out:
# Annotated corpus has been saved to annotated_corpus.csv
